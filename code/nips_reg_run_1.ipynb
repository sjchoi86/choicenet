# %% [markdown]
# # Run Regression Tasks

# %%
import nbloader
from nips_reg_config_1 import worker_class
if __name__ == "__main__": 
    print ("Packages loaded.")
# Out:
# Packages loaded.

# %% [markdown]
# ### Initiate Workers

# %%
nWorker = 12
maxGPU  = 2
WORKERS = ['']*nWorker 
for i in range(nWorker):
    WORKERS[i] = worker_class(_idx=i,_maxProcessID=nWorker,_maxGPU=maxGPU
                              ,_name='Worker_%02d'%(i),_VERBOSE=False)
    print ("[%d/%d] worker initiated."%(i,nWorker))
# Out:
# [0/12] worker initiated.
# [1/12] worker initiated.
# [2/12] worker initiated.
# [3/12] worker initiated.
# [4/12] worker initiated.
# [5/12] worker initiated.
# [6/12] worker initiated.
# [7/12] worker initiated.
# [8/12] worker initiated.
# [9/12] worker initiated.
# [10/12] worker initiated.
# [11/12] worker initiated.

# %% [markdown]
# ### Start Workers

# %%
for i in range(nWorker):
    WORKERS[i].start(); # Start process
# Out:
# Starting [Worker_00]
# Starting [Worker_01]
# Starting [Worker_02]
# Starting [Worker_03]
# Starting [Worker_04]
# Starting [Worker_05]
# Starting [Worker_06]
# Starting [Worker_07]
# Starting [Worker_08]
# Starting [Worker_09]
# Starting [Worker_10]
# Starting [Worker_11]
# processID:[0/12] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[1/12] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[2/12] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[3/12] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[4/12] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[5/12] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[6/12] GPU_ID:[0] #Config:[0]
# [Worker_06] Finished.
# processID:[7/12] GPU_ID:[1] #Config:[0]
# [Worker_07] Finished.
# processID:[8/12] GPU_ID:[0] #Config:[0]
# [Worker_08] Finished.
# processID:[9/12] GPU_ID:[1] #Config:[0]
# [Worker_09] Finished.
# processID:[10/12] GPU_ID:[0] #Config:[0]
# [Worker_10] Finished.
# processID:[11/12] GPU_ID:[1] #Config:[0]
# [Worker_11] Finished.
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv1e-06.txt
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv1e-08.txt
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv1e-04.txt
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv1.txt
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv1e-02.txt
# Text name: ../res/res_oRate60_noise5.0e-02_tauInv2.txt
# [Worker_04] Finished.
# [Worker_02] Finished.
# [Worker_03] Finished.
# [Worker_01] Finished.
# [Worker_05] Finished.
# [Worker_00] Finished.

# %% [markdown]
# # Run Regression Tasks

# %%
import nbloader
from main_reg_config import worker_class
if __name__ == "__main__": 
    print ("Packages loaded.")
# Out:
# Packages loaded.

# %% [markdown]
# ### Initiate Workers

# %%
nWorker = 16
maxGPU  = 8
WORKERS = ['']*nWorker 
for i in range(nWorker):
    WORKERS[i] = worker_class(_idx=i,_maxProcessID=nWorker,_maxGPU=maxGPU
                              ,_name='Worker_%02d'%(i),_VERBOSE=False)
    print ("[%d/%d] worker initiated."%(i,nWorker))
# Out:
# [0/16] worker initiated.
# [1/16] worker initiated.
# [2/16] worker initiated.
# [3/16] worker initiated.
# [4/16] worker initiated.
# [5/16] worker initiated.
# [6/16] worker initiated.
# [7/16] worker initiated.
# [8/16] worker initiated.
# [9/16] worker initiated.
# [10/16] worker initiated.
# [11/16] worker initiated.
# [12/16] worker initiated.
# [13/16] worker initiated.
# [14/16] worker initiated.
# [15/16] worker initiated.

# %% [markdown]
# ### Start Workers

# %%
for i in range(nWorker):
    WORKERS[i].start(); # Start process
# Out:
# Starting [Worker_00]
# Starting [Worker_01]
# Starting [Worker_02]
# Starting [Worker_03]
# Starting [Worker_04]
# Starting [Worker_05]
# Starting [Worker_06]
# processID:[0/16] GPU_ID:[0] #Config:[3]
# ===[0/3]===
# Starting [Worker_07]
# processID:[1/16] GPU_ID:[1] #Config:[3]
# processID:[2/16] GPU_ID:[2] #Config:[3]
# processID:[3/16] GPU_ID:[3] #Config:[3]
# ===[0/3]===
# ===[0/3]===
# ===[0/3]===
# Starting [Worker_08]
# processID:[4/16] GPU_ID:[4] #Config:[3]
# ===[0/3]===
# Starting [Worker_09]
# Starting [Worker_10]
# processID:[5/16] GPU_ID:[5] #Config:[3]
# ===[0/3]===
# Starting [Worker_11]
# processID:[6/16] GPU_ID:[6] #Config:[3]
# ===[0/3]===
# Starting [Worker_12]
# processID:[7/16] GPU_ID:[7] #Config:[3]
# ===[0/3]===
# Starting [Worker_13]
# processID:[8/16] GPU_ID:[0] #Config:[3]
# ===[0/3]===
# processID:[9/16] GPU_ID:[1] #Config:[3]
# Starting [Worker_14]
# processID:[10/16] GPU_ID:[2] #Config:[3]
# ===[0/3]===
# ===[0/3]===
# Starting [Worker_15]
# processID:[11/16] GPU_ID:[3] #Config:[3]
# ===[0/3]===
# processID:[12/16] GPU_ID:[4] #Config:[3]
# ===[0/3]===
# processID:[13/16] GPU_ID:[5] #Config:[2]
# ===[0/2]===
# processID:[14/16] GPU_ID:[6] #Config:[2]
# ===[0/2]===
# processID:[15/16] GPU_ID:[7] #Config:[2]
# ===[0/2]===
# Text name: ../res/res_MLP_cosexp_oRate0_var1.0e-06.txt
# Text name: ../res/res_CN_step_oRate10_var1.0e-06.txt
# Text name: ../res/res_CN_linear_oRate40_var1.0e-06.txt
# Text name: ../res/res_CN_step_oRate0_var1.0e-06.txt
# Text name: ../res/res_CN_step_oRate40_var1.0e-06.txt
# Text name: ../res/res_CN_linear_oRate0_var1.0e-06.txt
# Text name: ../res/res_CN_cosexp_oRate10_var1.0e-06.txt
# Text name: ../res/res_CN_linear_oRate10_var1.0e-06.txt
# Text name: ../res/res_CN_cosexp_oRate40_var1.0e-06.txt
# Text name: ../res/res_CN_linear_oRate20_var1.0e-06.txt
# Text name: ../res/res_CN_cosexp_oRate0_var1.0e-06.txt
# Text name: ../res/res_CN_step_oRate60_var1.0e-06.txt
# Text name: ../res/res_CN_cosexp_oRate20_var1.0e-06.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06.txt
# Text name: ../res/res_CN_step_oRate20_var1.0e-06.txt
# Text name: ../res/res_CN_linear_oRate60_var1.0e-06.txt
# ===[1/2]===
# Text name: ../res/res_MDN_cosexp_oRate10_var1.0e-06.txt
# [Worker_15] Finished.
# ===[1/3]===
# Text name: ../res/res_MLP_linear_oRate40_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_step_oRate40_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_cosexp_oRate10_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_linear_oRate60_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_step_oRate20_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_step_oRate0_var1.0e-06.txt
# ===[1/2]===
# Text name: ../res/res_MDN_cosexp_oRate0_var1.0e-06.txt
# ===[1/3]===
# ===[1/3]===
# Text name: ../res/res_MLP_cosexp_oRate40_var1.0e-06.txt
# Text name: ../res/res_MLP_step_oRate10_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_linear_oRate0_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_cosexp_oRate20_var1.0e-06.txt
# ===[1/2]===
# Text name: ../res/res_MLP_step_oRate60_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_linear_oRate20_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_linear_oRate10_var1.0e-06.txt
# ===[1/3]===
# Text name: ../res/res_MLP_cosexp_oRate60_var1.0e-06.txt

# %% [markdown]
# # Run Regression Tasks

# %%
import nbloader
from nips_reg_config_2 import worker_class
if __name__ == "__main__": 
    print ("Packages loaded.")
# Out:
# Packages loaded.

# %% [markdown]
# ### Initiate Workers

# %%
nWorker = 8
maxGPU  = 2
WORKERS = ['']*nWorker 
for i in range(nWorker):
    WORKERS[i] = worker_class(_idx=i,_maxProcessID=nWorker,_maxGPU=maxGPU
                              ,_name='Worker_%02d'%(i),_VERBOSE=False)
    print ("[%d/%d] worker initiated."%(i,nWorker))
# Out:
# [0/8] worker initiated.
# [1/8] worker initiated.
# [2/8] worker initiated.
# [3/8] worker initiated.
# [4/8] worker initiated.
# [5/8] worker initiated.
# [6/8] worker initiated.
# [7/8] worker initiated.

# %% [markdown]
# ### Start Workers

# %%
for i in range(nWorker):
    WORKERS[i].start(); # Start process
# Out:
# Starting [Worker_00]
# Starting [Worker_01]
# Starting [Worker_02]
# Starting [Worker_03]
# Starting [Worker_04]
# Starting [Worker_05]
# Starting [Worker_06]
# Starting [Worker_07]
# processID:[0/8] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[1/8] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[2/8] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[3/8] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[4/8] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[5/8] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# processID:[6/8] GPU_ID:[0] #Config:[1]
# ===[0/1]===
# processID:[7/8] GPU_ID:[1] #Config:[1]
# ===[0/1]===
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <string>:131: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix3.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix2.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix5.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix4.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix8.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix10.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix15.txt
# Text name: ../res/res_CN_cosexp_oRate60_var1.0e-06_kmix20.txt
# [Worker_00] Finished.
# [Worker_02] Finished.
# [Worker_01] Finished.
# [Worker_04] Finished.
# [Worker_03] Finished.
# [Worker_05] Finished.
# [Worker_06] Finished.
# [Worker_07] Finished.

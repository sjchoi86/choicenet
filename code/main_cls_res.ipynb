# %% [markdown]
# # Visualize Classification (MNIST) Results

# %%
import os,nbloader,warnings,glob
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from main_cls_config import errTypeList,outlierRatioList
from util import extract_percent,plot_mnist_accuracy,parse_accuracies,plot_mnist_accuracies
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print ("Package loaded.")
# Out:
# Package loaded.

# %% [markdown]
# ### Plot Learning Curves

# %%
for _mode in errTypeList:
    for _errRate in outlierRatioList:
        plot_mnist_accuracies(_mode=_mode,_errRate=_errRate*100,_SAVE_PNG=True)
# Out:
# ../fig/fig_mnistRes_rp_25.png saved.
# 25% Permutation (maxEpoch:51)
#   ConvNet: Best: 94.90 Last: 92.50
# ChoiceNet: Best: 99.30 Last: 99.20
# ../fig/fig_mnistRes_rp_45.png saved.
# 45% Permutation (maxEpoch:51)
#   ConvNet: Best: 68.20 Last: 63.50
# ChoiceNet: Best: 98.10 Last: 97.20
# ../fig/fig_mnistRes_rp_47.png saved.
# 47% Permutation (maxEpoch:51)
#   ConvNet: Best: 60.80 Last: 52.90
# ChoiceNet: Best: 92.70 Last: 88.30
# ../fig/fig_mnistRes_rs_50.png saved.
# 50% Random Shuffle (maxEpoch:51)
#   ConvNet: Best: 97.00 Last: 95.90
# ChoiceNet: Best: 99.10 Last: 99.10
# ../fig/fig_mnistRes_rs_90.png saved.
# 90% Random Shuffle (maxEpoch:51)
#   ConvNet: Best: 77.10 Last: 53.10
# ChoiceNet: Best: 95.90 Last: 95.30
# ../fig/fig_mnistRes_rs_95.png saved.
# 95% Random Shuffle (maxEpoch:51)
#   ConvNet: Best: 50.40 Last: 32.40
# ChoiceNet: Best: 84.10 Last: 64.80
# ../fig/fig_mnistRes_b_25.png saved.
# 25% Label Bias (maxEpoch:51)
#   ConvNet: Best: 95.20 Last: 89.60
# ...

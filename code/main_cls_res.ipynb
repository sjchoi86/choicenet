# %% [markdown]
# # Visualize Classification (MNIST) Results

# %%
import os,nbloader,warnings,glob
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from main_cls_config import errTypeList,outlierRatioList
from util import extract_percent,plot_mnist_accuracy,parse_accuracies,plot_mnist_accuracies
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print ("Package loaded.")
# Out:
# Package loaded.

# %% [markdown]
# ### Plot Learning Curves

# %%
for _mode in errTypeList:
    for _errRate in outlierRatioList:
        plot_mnist_accuracies(_mode=_mode,_errRate=_errRate*100,_SAVE_PNG=True)
# Out:
# ../fig/fig_mnistRes_rp_25.png saved.
# 25% Permutation (maxEpoch:41)
#   ConvNet: Best: 94.70 Last: 94.40
# ChoiceNet: Best: 99.00 Last: 99.00
# ../fig/fig_mnistRes_rp_45.png saved.
# 45% Permutation (maxEpoch:41)
#   ConvNet: Best: 67.00 Last: 63.50
# ChoiceNet: Best: 98.10 Last: 98.00
# ../fig/fig_mnistRes_rp_47.png saved.
# 47% Permutation (maxEpoch:41)
#   ConvNet: Best: 60.30 Last: 56.80
# ChoiceNet: Best: 92.20 Last: 92.10
# ../fig/fig_mnistRes_rs_50.png saved.
# 50% Random Shuffle (maxEpoch:41)
#   ConvNet: Best: 97.10 Last: 97.00
# ChoiceNet: Best: 98.80 Last: 98.70
# ../fig/fig_mnistRes_rs_90.png saved.
# 90% Random Shuffle (maxEpoch:41)
#   ConvNet: Best: 76.20 Last: 73.30
# ChoiceNet: Best: 95.30 Last: 95.20
# ../fig/fig_mnistRes_rs_95.png saved.
# 95% Random Shuffle (maxEpoch:41)
#   ConvNet: Best: 51.80 Last: 45.70
# ChoiceNet: Best: 84.80 Last: 84.40
# ../fig/fig_mnistRes_b_25.png saved.
# 25% Label Bias (maxEpoch:41)
#   ConvNet: Best: 94.60 Last: 92.10
# ChoiceNet: Best: 98.90 Last: 98.90
# ../fig/fig_mnistRes_b_45.png saved.
# 45% Label Bias (maxEpoch:41)
#   ConvNet: Best: 73.80 Last: 64.90
# ChoiceNet: Best: 94.70 Last: 94.30
# ../fig/fig_mnistRes_b_47.png saved.
# 47% Label Bias (maxEpoch:41)
#   ConvNet: Best: 68.50 Last: 58.90
# ChoiceNet: Best: 88.10 Last: 87.30

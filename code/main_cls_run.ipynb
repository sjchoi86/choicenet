# %% [markdown]
# # Run Classification (MNIST) Tasks

# %%
import nbloader
from main_cls_config import worker_class
if __name__ == "__main__": 
    print ("Packages loaded.")
# Out:
# Packages loaded.

# %% [markdown]
# ### Instantiate Workers

# %%
nWorker = 16
maxGPU  = 8
WORKERS = ['']*nWorker
for i in range(nWorker):
    WORKERS[i] = worker_class(_idx=i,_maxProcessID=nWorker,_maxGPU=maxGPU,_name='Worker_%02d'%(i)
                              ,_period=1.0,_maxTick=10,_VERBOSE=True)
# Out:
# [Worker_00] Instantiated.
# [Worker_01] Instantiated.
# [Worker_02] Instantiated.
# [Worker_03] Instantiated.
# [Worker_04] Instantiated.
# [Worker_05] Instantiated.
# [Worker_06] Instantiated.
# [Worker_07] Instantiated.
# [Worker_08] Instantiated.
# [Worker_09] Instantiated.
# [Worker_10] Instantiated.
# [Worker_11] Instantiated.
# [Worker_12] Instantiated.
# [Worker_13] Instantiated.
# [Worker_14] Instantiated.
# [Worker_15] Instantiated.

# %% [markdown]
# ### Start Workers

# %%
for i in range(nWorker):
    WORKERS[i].start(); # Start process
# Out:
# Starting [Worker_00]
# Starting [Worker_01]
# Starting [Worker_02]
# Starting [Worker_03]
# Starting [Worker_04]
# Starting [Worker_05]
# Starting [Worker_06]
# Starting [Worker_07]
# Starting [Worker_08]
# Starting [Worker_09]
# Starting [Worker_10]
# Starting [Worker_11]
# Starting [Worker_12]
# Starting [Worker_13]
# Starting [Worker_14]
# Starting [Worker_15]
# processID:[0/16] GPU_ID:[0] #Config:[2]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[1/16] GPU_ID:[1] #Config:[2]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[2/16] GPU_ID:[2] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[3/16] GPU_ID:[3] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[4/16] GPU_ID:[4] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[5/16] GPU_ID:[5] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[6/16] GPU_ID:[6] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[7/16] GPU_ID:[7] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[8/16] GPU_ID:[0] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[9/16] GPU_ID:[1] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[10/16] GPU_ID:[2] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[11/16] GPU_ID:[3] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[12/16] GPU_ID:[4] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[13/16] GPU_ID:[5] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[14/16] GPU_ID:[6] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[15/16] GPU_ID:[7] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Text name: ../res/res_mnist_b_err90_basic_cnn.txt
# Text name: ../res/res_mnist_rs_err90_basic_cnn.txt
# Text name: ../res/res_mnist_b_err50_basic_cnn.txt
# Text name: ../res/res_mnist_rs_err50_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err90_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err95_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err50_basic_cnn.txt
# Text name: ../res/res_mnist_b_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err50_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_b_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err50_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_b_err50_basic_choiceNet.txt
# [00/50] [Loss] train:0.953 val:0.999 test:0.998 [Accr] train:54.7% val:55.4% test:55.7% maxVal:55.4% maxTest:55.7%
# [00/50] [Loss] train:2.339 val:1.972 test:1.957 [Accr] train:13.6% val:40.9% test:42.1% maxVal:40.9% maxTest:42.1%
# [00/50] [Loss] train:1.871 val:0.983 test:0.988 [Accr] train:48.1% val:87.0% test:87.0% maxVal:87.0% maxTest:87.0%
# [00/50] [Loss] train:0.862 val:0.623 test:0.623 [Accr] train:66.9% val:81.4% test:80.9% maxVal:81.4% maxTest:80.9%
# [00/50] [Loss] train:1.208 val:1.050 test:1.054 [Accr] train:46.4% val:59.9% test:60.0% maxVal:59.9% maxTest:60.0%
# [00/50] [Loss] train:1.219 val:1.139 test:1.151 [Accr] train:45.5% val:53.0% test:52.7% maxVal:53.0% maxTest:52.7%
# [00/50] [Loss] train:1.056 val:0.646 test:0.651 [Accr] train:65.7% val:86.9% test:86.2% maxVal:86.9% maxTest:86.2%
# [01/50] [Loss] train:0.847 val:0.880 test:0.894 [Accr] train:56.0% val:59.0% test:57.5% maxVal:59.0% maxTest:57.5%
# [01/50] [Loss] train:2.301 val:1.923 test:1.914 [Accr] train:15.2% val:53.8% test:55.0% maxVal:53.8% maxTest:55.0%
# [01/50] [Loss] train:1.814 val:0.897 test:0.900 [Accr] train:50.6% val:91.7% test:91.7% maxVal:91.7% maxTest:91.7%
# [01/50] [Loss] train:0.745 val:0.520 test:0.529 [Accr] train:69.1% val:84.6% test:83.2% maxVal:84.6% maxTest:83.2%
# [01/50] [Loss] train:1.038 val:0.917 test:0.922 [Accr] train:49.3% val:62.3% test:61.8% maxVal:62.3% maxTest:61.8%
# [01/50] [Loss] train:1.045 val:1.001 test:1.011 [Accr] train:48.4% val:50.9% test:51.0% maxVal:53.0% maxTest:52.7%
# [01/50] [Loss] train:0.893 val:0.536 test:0.540 [Accr] train:68.5% val:90.1% test:89.0% maxVal:90.1% maxTest:89.0%
# [00/50] [Loss] train:0.051(f:-0.114+r:0.049+k:0.001+l:0.116) val:-0.059 test:-0.070 [Accr] train:15.3% val:59.1% test:61.3% maxVal:59.1% maxTest:61.3%
# [00/50] [Loss] train:-0.103(f:-0.278+r:0.059+k:0.001+l:0.116) val:-0.212 test:-0.222 [Accr] train:43.9% val:70.0% test:71.7% maxVal:70.0% maxTest:71.7%
# [00/50] [Loss] train:-0.148(f:-0.327+r:0.062+k:0.001+l:0.116) val:-0.265 test:-0.268 [Accr] train:53.1% val:79.5% test:78.7% maxVal:79.5% maxTest:78.7%
# [00/50] [Loss] train:0.059(f:-0.105+r:0.047+k:0.001+l:0.116) val:0.011 test:0.002 [Accr] train:12.0% val:36.5% test:38.9% maxVal:36.5% maxTest:38.9%
# [02/50] [Loss] train:0.799 val:0.833 test:0.843 [Accr] train:56.8% val:59.7% test:58.4% maxVal:59.7% maxTest:58.4%
# [00/50] [Loss] train:-0.112(f:-0.288+r:0.059+k:0.001+l:0.116) val:-0.242 test:-0.248 [Accr] train:45.7% val:73.9% test:75.4% maxVal:73.9% maxTest:75.4%
# [00/50] [Loss] train:-0.110(f:-0.288+r:0.061+k:0.001+l:0.116) val:-0.302 test:-0.308 [Accr] train:47.8% val:86.2% test:86.7% maxVal:86.2% maxTest:86.7%
# [00/50] [Loss] train:-0.141(f:-0.319+r:0.061+k:0.001+l:0.116) val:-0.246 test:-0.249 [Accr] train:51.7% val:76.8% test:76.0% maxVal:76.8% maxTest:76.0%
# [00/50] [Loss] train:-0.216(f:-0.396+r:0.063+k:0.001+l:0.116) val:-0.332 test:-0.340 [Accr] train:65.9% val:88.2% test:88.2% maxVal:88.2% maxTest:88.2%
# [00/50] [Loss] train:-0.237(f:-0.418+r:0.064+k:0.001+l:0.116) val:-0.338 test:-0.342 [Accr] train:68.3% val:88.0% test:87.8% maxVal:88.0% maxTest:87.8%
# [02/50] [Loss] train:2.286 val:1.909 test:1.903 [Accr] train:15.9% val:61.1% test:62.3% maxVal:61.1% maxTest:62.3%
# [02/50] [Loss] train:1.787 val:0.842 test:0.853 [Accr] train:51.7% val:93.6% test:93.4% maxVal:93.6% maxTest:93.4%
# [02/50] [Loss] train:0.692 val:0.433 test:0.446 [Accr] train:71.7% val:89.1% test:87.4% maxVal:89.1% maxTest:87.4%
# [02/50] [Loss] train:0.964 val:0.927 test:0.938 [Accr] train:50.1% val:52.5% test:53.5% maxVal:53.0% maxTest:52.7%
# [02/50] [Loss] train:0.956 val:0.864 test:0.872 [Accr] train:50.7% val:60.7% test:60.9% maxVal:62.3% maxTest:61.8%
# [02/50] [Loss] train:0.817 val:0.471 test:0.474 [Accr] train:70.1% val:90.8% test:90.8% maxVal:90.8% maxTest:90.8%
# [03/50] [Loss] train:0.775 val:0.827 test:0.842 [Accr] train:57.3% val:57.6% test:56.6% maxVal:59.7% maxTest:58.4%
# [01/50] [Loss] train:0.043(f:-0.123+r:0.050+k:0.001+l:0.115) val:-0.151 test:-0.156 [Accr] train:16.9% val:76.9% test:78.2% maxVal:76.9% maxTest:78.2%
# [01/50] [Loss] train:-0.144(f:-0.325+r:0.064+k:0.001+l:0.115) val:-0.294 test:-0.298 [Accr] train:46.6% val:75.1% test:75.8% maxVal:75.1% maxTest:75.8%
# [03/50] [Loss] train:2.277 val:1.901 test:1.895 [Accr] train:16.7% val:65.9% test:66.8% maxVal:65.9% maxTest:66.8%
# [01/50] [Loss] train:-0.196(f:-0.379+r:0.067+k:0.001+l:0.115) val:-0.362 test:-0.361 [Accr] train:55.2% val:85.8% test:84.8% maxVal:85.8% maxTest:84.8%
# [01/50] [Loss] train:0.056(f:-0.107+r:0.047+k:0.001+l:0.115) val:-0.042 test:-0.048 [Accr] train:13.0% val:54.8% test:56.7% maxVal:54.8% maxTest:56.7%
# [01/50] [Loss] train:-0.156(f:-0.340+r:0.067+k:0.001+l:0.115) val:-0.406 test:-0.407 [Accr] train:50.5% val:91.8% test:91.9% maxVal:91.8% maxTest:91.9%
# [01/50] [Loss] train:-0.158(f:-0.339+r:0.065+k:0.001+l:0.115) val:-0.340 test:-0.341 [Accr] train:49.1% val:82.1% test:83.2% maxVal:82.1% maxTest:83.2%
# [01/50] [Loss] train:-0.183(f:-0.365+r:0.066+k:0.001+l:0.115) val:-0.335 test:-0.333 [Accr] train:53.5% val:82.3% test:81.3% maxVal:82.3% maxTest:81.3%
# [01/50] [Loss] train:-0.285(f:-0.471+r:0.070+k:0.001+l:0.115) val:-0.435 test:-0.437 [Accr] train:69.4% val:92.9% test:93.0% maxVal:92.9% maxTest:93.0%
# [01/50] [Loss] train:-0.309(f:-0.496+r:0.070+k:0.001+l:0.115) val:-0.441 test:-0.441 [Accr] train:71.8% val:92.7% test:92.7% maxVal:92.7% maxTest:92.7%
# [03/50] [Loss] train:1.771 val:0.852 test:0.857 [Accr] train:52.1% val:94.5% test:94.3% maxVal:94.5% maxTest:94.3%
# [03/50] [Loss] train:0.663 val:0.427 test:0.439 [Accr] train:72.0% val:88.8% test:87.5% maxVal:89.1% maxTest:87.4%
# [03/50] [Loss] train:0.916 val:0.854 test:0.865 [Accr] train:51.5% val:58.6% test:58.1% maxVal:58.6% maxTest:58.1%
# [03/50] [Loss] train:0.911 val:0.819 test:0.824 [Accr] train:52.1% val:61.2% test:61.7% maxVal:62.3% maxTest:61.8%
# [03/50] [Loss] train:0.773 val:0.447 test:0.449 [Accr] train:70.6% val:91.7% test:91.6% maxVal:91.7% maxTest:91.6%
# [04/50] [Loss] train:0.750 val:0.796 test:0.815 [Accr] train:58.0% val:59.4% test:57.8% maxVal:59.7% maxTest:58.4%
# [04/50] [Loss] train:2.272 val:1.927 test:1.925 [Accr] train:16.9% val:67.6% test:68.0% maxVal:67.6% maxTest:68.0%
# [04/50] [Loss] train:0.886 val:0.845 test:0.862 [Accr] train:51.9% val:57.6% test:55.9% maxVal:58.6% maxTest:58.1%
# [04/50] [Loss] train:1.756 val:0.793 test:0.804 [Accr] train:52.4% val:95.1% test:94.9% maxVal:95.1% maxTest:94.9%
# [04/50] [Loss] train:0.640 val:0.455 test:0.471 [Accr] train:71.8% val:87.0% test:85.8% maxVal:89.1% maxTest:87.4%
# [04/50] [Loss] train:0.878 val:0.797 test:0.804 [Accr] train:53.1% val:62.7% test:61.9% maxVal:62.7% maxTest:61.9%
# [04/50] [Loss] train:0.738 val:0.440 test:0.443 [Accr] train:71.2% val:92.1% test:92.0% maxVal:92.1% maxTest:92.0%
# [05/50] [Loss] train:0.731 val:0.710 test:0.721 [Accr] train:59.5% val:67.1% test:65.7% maxVal:67.1% maxTest:65.7%
# [02/50] [Loss] train:0.037(f:-0.130+r:0.051+k:0.001+l:0.115) val:-0.209 test:-0.216 [Accr] train:17.6% val:83.2% test:84.1% maxVal:83.2% maxTest:84.1%
# [02/50] [Loss] train:-0.168(f:-0.350+r:0.066+k:0.001+l:0.115) val:-0.338 test:-0.342 [Accr] train:48.2% val:77.5% test:78.0% maxVal:77.5% maxTest:78.0%
# [02/50] [Loss] train:-0.220(f:-0.406+r:0.070+k:0.001+l:0.115) val:-0.408 test:-0.406 [Accr] train:56.1% val:87.8% test:86.9% maxVal:87.8% maxTest:86.9%
# [02/50] [Loss] train:0.053(f:-0.110+r:0.046+k:0.001+l:0.115) val:-0.073 test:-0.083 [Accr] train:13.6% val:67.1% test:69.2% maxVal:67.1% maxTest:69.2%
# [02/50] [Loss] train:-0.181(f:-0.367+r:0.070+k:0.001+l:0.115) val:-0.458 test:-0.457 [Accr] train:51.6% val:94.0% test:94.0% maxVal:94.0% maxTest:94.0%
# [02/50] [Loss] train:-0.181(f:-0.366+r:0.068+k:0.001+l:0.115) val:-0.386 test:-0.388 [Accr] train:50.9% val:88.2% test:88.6% maxVal:88.2% maxTest:88.6%
# [02/50] [Loss] train:-0.207(f:-0.392+r:0.069+k:0.001+l:0.115) val:-0.380 test:-0.377 [Accr] train:54.4% val:84.6% test:83.6% maxVal:84.6% maxTest:83.6%
# [02/50] [Loss] train:-0.324(f:-0.513+r:0.073+k:0.001+l:0.115) val:-0.489 test:-0.489 [Accr] train:70.9% val:94.8% test:94.9% maxVal:94.8% maxTest:94.9%
# [02/50] [Loss] train:-0.343(f:-0.534+r:0.074+k:0.001+l:0.115) val:-0.488 test:-0.487 [Accr] train:73.6% val:94.8% test:95.0% maxVal:94.8% maxTest:95.0%
# [05/50] [Loss] train:2.265 val:1.867 test:1.868 [Accr] train:17.5% val:73.5% test:73.4% maxVal:73.5% maxTest:73.4%
# [05/50] [Loss] train:0.862 val:0.871 test:0.885 [Accr] train:52.7% val:51.0% test:50.0% maxVal:58.6% maxTest:58.1%
# [05/50] [Loss] train:1.745 val:0.784 test:0.797 [Accr] train:52.8% val:95.8% test:95.3% maxVal:95.8% maxTest:95.3%
# [05/50] [Loss] train:0.854 val:0.778 test:0.783 [Accr] train:54.1% val:65.2% test:63.2% maxVal:65.2% maxTest:63.2%
# [05/50] [Loss] train:0.621 val:0.409 test:0.422 [Accr] train:73.2% val:90.1% test:89.3% maxVal:90.1% maxTest:89.3%
# [05/50] [Loss] train:0.718 val:0.416 test:0.425 [Accr] train:71.7% val:92.5% test:92.1% maxVal:92.5% maxTest:92.1%
# [06/50] [Loss] train:0.724 val:0.762 test:0.781 [Accr] train:59.4% val:61.5% test:59.7% maxVal:67.1% maxTest:65.7%
# [06/50] [Loss] train:2.260 val:1.847 test:1.846 [Accr] train:17.9% val:75.8% test:75.1% maxVal:75.8% maxTest:75.1%
# [03/50] [Loss] train:0.034(f:-0.133+r:0.051+k:0.001+l:0.115) val:-0.237 test:-0.246 [Accr] train:17.8% val:85.7% test:86.5% maxVal:85.7% maxTest:86.5%
# [06/50] [Loss] train:0.838 val:0.816 test:0.822 [Accr] train:53.7% val:56.2% test:56.0% maxVal:58.6% maxTest:58.1%
# [03/50] [Loss] train:-0.237(f:-0.426+r:0.072+k:0.001+l:0.115) val:-0.443 test:-0.444 [Accr] train:56.5% val:89.5% test:88.6% maxVal:89.5% maxTest:88.6%
# [03/50] [Loss] train:-0.184(f:-0.368+r:0.068+k:0.001+l:0.115) val:-0.365 test:-0.374 [Accr] train:49.1% val:78.4% test:78.9% maxVal:78.4% maxTest:78.9%
# [06/50] [Loss] train:0.835 val:0.774 test:0.778 [Accr] train:54.8% val:63.5% test:63.0% maxVal:65.2% maxTest:63.2%
# [03/50] [Loss] train:0.050(f:-0.111+r:0.045+k:0.001+l:0.115) val:-0.096 test:-0.108 [Accr] train:13.8% val:71.2% test:73.0% maxVal:71.2% maxTest:73.0%
# [06/50] [Loss] train:1.731 val:0.772 test:0.786 [Accr] train:53.0% val:96.0% test:96.0% maxVal:96.0% maxTest:96.0%
# [03/50] [Loss] train:-0.199(f:-0.388+r:0.073+k:0.001+l:0.115) val:-0.494 test:-0.494 [Accr] train:52.4% val:95.1% test:95.2% maxVal:95.1% maxTest:95.2%
# [06/50] [Loss] train:0.608 val:0.385 test:0.398 [Accr] train:73.9% val:90.5% test:89.4% maxVal:90.5% maxTest:89.4%
# [03/50] [Loss] train:-0.199(f:-0.386+r:0.071+k:0.001+l:0.115) val:-0.420 test:-0.427 [Accr] train:51.9% val:91.3% test:91.6% maxVal:91.3% maxTest:91.6%
# [03/50] [Loss] train:-0.222(f:-0.409+r:0.071+k:0.001+l:0.115) val:-0.413 test:-0.414 [Accr] train:54.8% val:86.6% test:85.5% maxVal:86.6% maxTest:85.5%
# [07/50] [Loss] train:0.708 val:0.700 test:0.716 [Accr] train:60.5% val:66.2% test:64.4% maxVal:67.1% maxTest:65.7%
# [06/50] [Loss] train:0.699 val:0.407 test:0.409 [Accr] train:72.0% val:93.3% test:92.9% maxVal:93.3% maxTest:92.9%
# [03/50] [Loss] train:-0.347(f:-0.539+r:0.076+k:0.001+l:0.115) val:-0.520 test:-0.520 [Accr] train:71.9% val:95.9% test:95.9% maxVal:95.9% maxTest:95.9%
# [03/50] [Loss] train:-0.370(f:-0.563+r:0.077+k:0.001+l:0.115) val:-0.522 test:-0.521 [Accr] train:74.4% val:95.9% test:96.0% maxVal:95.9% maxTest:96.0%
# [07/50] [Loss] train:2.257 val:1.855 test:1.860 [Accr] train:18.0% val:73.5% test:72.0% maxVal:75.8% maxTest:75.1%
# [07/50] [Loss] train:0.818 val:0.775 test:0.785 [Accr] train:54.9% val:60.6% test:60.3% maxVal:60.6% maxTest:60.3%
# [07/50] [Loss] train:0.814 val:0.756 test:0.762 [Accr] train:55.6% val:63.6% test:63.2% maxVal:65.2% maxTest:63.2%
# [07/50] [Loss] train:1.723 val:0.758 test:0.775 [Accr] train:53.1% val:96.1% test:96.0% maxVal:96.1% maxTest:96.0%
# [07/50] [Loss] train:0.593 val:0.384 test:0.396 [Accr] train:74.4% val:91.3% test:90.4% maxVal:91.3% maxTest:90.4%
# [08/50] [Loss] train:0.703 val:0.621 test:0.625 [Accr] train:60.9% val:73.7% test:73.9% maxVal:73.7% maxTest:73.9%
# [07/50] [Loss] train:0.680 val:0.415 test:0.412 [Accr] train:72.5% val:93.4% test:93.0% maxVal:93.4% maxTest:93.0%
# [04/50] [Loss] train:0.032(f:-0.136+r:0.051+k:0.001+l:0.115) val:-0.256 test:-0.266 [Accr] train:18.0% val:88.0% test:88.5% maxVal:88.0% maxTest:88.5%
# [04/50] [Loss] train:-0.250(f:-0.439+r:0.073+k:0.001+l:0.115) val:-0.469 test:-0.468 [Accr] train:56.9% val:90.3% test:89.4% maxVal:90.3% maxTest:89.4%
# [04/50] [Loss] train:-0.194(f:-0.380+r:0.070+k:0.001+l:0.115) val:-0.387 test:-0.393 [Accr] train:49.8% val:80.0% test:81.0% maxVal:80.0% maxTest:81.0%
# [04/50] [Loss] train:0.048(f:-0.113+r:0.045+k:0.001+l:0.115) val:-0.108 test:-0.120 [Accr] train:14.0% val:75.0% test:75.8% maxVal:75.0% maxTest:75.8%
# [04/50] [Loss] train:-0.212(f:-0.402+r:0.074+k:0.001+l:0.115) val:-0.521 test:-0.520 [Accr] train:52.9% val:96.0% test:96.1% maxVal:96.0% maxTest:96.1%
# [04/50] [Loss] train:-0.235(f:-0.423+r:0.071+k:0.001+l:0.115) val:-0.437 test:-0.436 [Accr] train:55.1% val:87.2% test:86.0% maxVal:87.2% maxTest:86.0%
# [04/50] [Loss] train:-0.212(f:-0.401+r:0.072+k:0.001+l:0.115) val:-0.447 test:-0.451 [Accr] train:52.6% val:93.0% test:93.3% maxVal:93.0% maxTest:93.3%
# [08/50] [Loss] train:2.250 val:1.836 test:1.837 [Accr] train:18.4% val:77.1% test:77.1% maxVal:77.1% maxTest:77.1%
# [04/50] [Loss] train:-0.365(f:-0.559+r:0.077+k:0.001+l:0.115) val:-0.546 test:-0.545 [Accr] train:72.5% val:96.6% test:96.6% maxVal:96.6% maxTest:96.6%
# [08/50] [Loss] train:0.810 val:0.794 test:0.803 [Accr] train:55.2% val:58.3% test:57.7% maxVal:60.6% maxTest:60.3%
# [04/50] [Loss] train:-0.384(f:-0.578+r:0.077+k:0.001+l:0.115) val:-0.544 test:-0.543 [Accr] train:75.0% val:96.6% test:96.5% maxVal:96.6% maxTest:96.5%
# [08/50] [Loss] train:0.802 val:0.732 test:0.739 [Accr] train:56.4% val:65.6% test:65.2% maxVal:65.6% maxTest:65.2%
# [08/50] [Loss] train:1.714 val:0.748 test:0.762 [Accr] train:53.3% val:96.4% test:96.4% maxVal:96.4% maxTest:96.4%
# [08/50] [Loss] train:0.600 val:0.300 test:0.304 [Accr] train:75.6% val:94.9% test:94.5% maxVal:94.9% maxTest:94.5%
# [09/50] [Loss] train:0.688 val:0.695 test:0.697 [Accr] train:61.6% val:64.6% test:65.1% maxVal:73.7% maxTest:73.9%
# [08/50] [Loss] train:0.666 val:0.406 test:0.407 [Accr] train:72.8% val:93.4% test:93.2% maxVal:93.4% maxTest:93.0%
# [09/50] [Loss] train:2.246 val:1.859 test:1.859 [Accr] train:18.5% val:74.7% test:74.0% maxVal:77.1% maxTest:77.1%
# [09/50] [Loss] train:0.793 val:0.793 test:0.802 [Accr] train:56.1% val:57.1% test:56.2% maxVal:60.6% maxTest:60.3%
# [09/50] [Loss] train:0.788 val:0.768 test:0.774 [Accr] train:56.9% val:59.8% test:59.0% maxVal:65.6% maxTest:65.2%
# [05/50] [Loss] train:0.029(f:-0.137+r:0.051+k:0.001+l:0.115) val:-0.280 test:-0.284 [Accr] train:18.2% val:89.8% test:89.8% maxVal:89.8% maxTest:89.8%
# [09/50] [Loss] train:1.708 val:0.773 test:0.787 [Accr] train:53.3% val:96.3% test:96.3% maxVal:96.4% maxTest:96.4%
# [05/50] [Loss] train:-0.263(f:-0.453+r:0.074+k:0.001+l:0.115) val:-0.489 test:-0.487 [Accr] train:57.2% val:91.0% test:89.6% maxVal:91.0% maxTest:89.6%
# [05/50] [Loss] train:-0.206(f:-0.393+r:0.071+k:0.001+l:0.115) val:-0.408 test:-0.413 [Accr] train:50.3% val:81.2% test:82.3% maxVal:81.2% maxTest:82.3%
# [10/50] [Loss] train:0.681 val:0.633 test:0.641 [Accr] train:62.0% val:71.5% test:71.0% maxVal:73.7% maxTest:73.9%
# [05/50] [Loss] train:0.046(f:-0.114+r:0.044+k:0.001+l:0.115) val:-0.124 test:-0.136 [Accr] train:14.2% val:76.3% test:78.0% maxVal:76.3% maxTest:78.0%
# [09/50] [Loss] train:0.574 val:0.396 test:0.404 [Accr] train:74.5% val:90.2% test:89.3% maxVal:94.9% maxTest:94.5%
# [09/50] [Loss] train:0.653 val:0.402 test:0.404 [Accr] train:73.1% val:93.3% test:93.2% maxVal:93.4% maxTest:93.0%
# [05/50] [Loss] train:-0.221(f:-0.412+r:0.075+k:0.001+l:0.115) val:-0.540 test:-0.538 [Accr] train:53.2% val:96.5% test:96.6% maxVal:96.5% maxTest:96.6%
# [05/50] [Loss] train:-0.248(f:-0.437+r:0.072+k:0.001+l:0.115) val:-0.453 test:-0.450 [Accr] train:55.2% val:87.0% test:85.5% maxVal:87.2% maxTest:86.0%
# [05/50] [Loss] train:-0.221(f:-0.410+r:0.073+k:0.001+l:0.115) val:-0.469 test:-0.472 [Accr] train:53.0% val:94.7% test:94.7% maxVal:94.7% maxTest:94.7%
# [05/50] [Loss] train:-0.378(f:-0.573+r:0.079+k:0.001+l:0.115) val:-0.565 test:-0.563 [Accr] train:72.8% val:97.0% test:97.1% maxVal:97.0% maxTest:97.1%
# [05/50] [Loss] train:-0.399(f:-0.594+r:0.079+k:0.001+l:0.115) val:-0.563 test:-0.561 [Accr] train:75.3% val:97.2% test:97.0% maxVal:97.2% maxTest:97.0%
# [10/50] [Loss] train:2.240 val:1.834 test:1.840 [Accr] train:18.8% val:76.5% test:75.4% maxVal:77.1% maxTest:77.1%
# [10/50] [Loss] train:0.783 val:0.779 test:0.779 [Accr] train:56.4% val:56.7% test:57.2% maxVal:60.6% maxTest:60.3%
# [10/50] [Loss] train:0.782 val:0.761 test:0.758 [Accr] train:57.1% val:58.9% test:58.9% maxVal:65.6% maxTest:65.2%
# [10/50] [Loss] train:1.698 val:0.743 test:0.757 [Accr] train:53.5% val:96.9% test:96.6% maxVal:96.9% maxTest:96.6%
# [11/50] [Loss] train:0.681 val:0.815 test:0.822 [Accr] train:61.6% val:50.3% test:50.5% maxVal:73.7% maxTest:73.9%
# [10/50] [Loss] train:0.567 val:0.323 test:0.331 [Accr] train:75.8% val:94.0% test:93.2% maxVal:94.9% maxTest:94.5%
# [10/50] [Loss] train:0.643 val:0.373 test:0.377 [Accr] train:73.5% val:94.2% test:93.8% maxVal:94.2% maxTest:93.8%
# [06/50] [Loss] train:0.027(f:-0.139+r:0.050+k:0.001+l:0.115) val:-0.289 test:-0.297 [Accr] train:18.3% val:91.5% test:91.4% maxVal:91.5% maxTest:91.4%
# [06/50] [Loss] train:-0.271(f:-0.461+r:0.075+k:0.001+l:0.115) val:-0.505 test:-0.503 [Accr] train:57.5% val:91.8% test:90.6% maxVal:91.8% maxTest:90.6%
# [06/50] [Loss] train:-0.214(f:-0.401+r:0.072+k:0.001+l:0.115) val:-0.420 test:-0.428 [Accr] train:50.5% val:82.4% test:83.3% maxVal:82.4% maxTest:83.3%
# [11/50] [Loss] train:2.237 val:1.836 test:1.837 [Accr] train:19.0% val:74.5% test:74.8% maxVal:77.1% maxTest:77.1%
# [06/50] [Loss] train:0.044(f:-0.114+r:0.042+k:0.001+l:0.115) val:-0.131 test:-0.142 [Accr] train:14.4% val:78.6% test:79.9% maxVal:78.6% maxTest:79.9%
# [11/50] [Loss] train:0.772 val:0.795 test:0.802 [Accr] train:57.2% val:55.9% test:55.0% maxVal:60.6% maxTest:60.3%
# [06/50] [Loss] train:-0.231(f:-0.422+r:0.076+k:0.001+l:0.115) val:-0.558 test:-0.556 [Accr] train:53.4% val:97.0% test:97.0% maxVal:97.0% maxTest:97.0%
# [06/50] [Loss] train:-0.255(f:-0.444+r:0.073+k:0.001+l:0.115) val:-0.468 test:-0.465 [Accr] train:55.5% val:87.7% test:86.3% maxVal:87.7% maxTest:86.3%
# [11/50] [Loss] train:0.766 val:0.730 test:0.735 [Accr] train:58.2% val:62.8% test:62.3% maxVal:65.6% maxTest:65.2%
# [06/50] [Loss] train:-0.230(f:-0.419+r:0.074+k:0.001+l:0.115) val:-0.483 test:-0.487 [Accr] train:53.3% val:95.6% test:95.5% maxVal:95.6% maxTest:95.5%
# [12/50] [Loss] train:0.666 val:0.609 test:0.612 [Accr] train:62.9% val:74.0% test:73.5% maxVal:74.0% maxTest:73.5%
# [06/50] [Loss] train:-0.389(f:-0.585+r:0.080+k:0.001+l:0.115) val:-0.579 test:-0.578 [Accr] train:73.0% val:97.4% test:97.4% maxVal:97.4% maxTest:97.4%
# [11/50] [Loss] train:1.692 val:0.748 test:0.764 [Accr] train:53.5% val:97.1% test:96.7% maxVal:97.1% maxTest:96.7%
# [11/50] [Loss] train:0.564 val:0.412 test:0.418 [Accr] train:74.6% val:88.9% test:88.1% maxVal:94.9% maxTest:94.5%
# [06/50] [Loss] train:-0.410(f:-0.605+r:0.079+k:0.001+l:0.115) val:-0.577 test:-0.575 [Accr] train:75.5% val:97.4% test:97.3% maxVal:97.4% maxTest:97.3%
# [11/50] [Loss] train:0.633 val:0.385 test:0.388 [Accr] train:73.6% val:93.6% test:93.3% maxVal:94.2% maxTest:93.8%
# [12/50] [Loss] train:2.232 val:1.823 test:1.831 [Accr] train:19.3% val:76.2% test:75.0% maxVal:77.1% maxTest:77.1%
# [12/50] [Loss] train:0.762 val:0.747 test:0.753 [Accr] train:58.0% val:61.0% test:60.6% maxVal:61.0% maxTest:60.6%
# [12/50] [Loss] train:0.756 val:0.702 test:0.698 [Accr] train:58.8% val:67.7% test:67.6% maxVal:67.7% maxTest:67.6%
# [13/50] [Loss] train:0.659 val:0.656 test:0.655 [Accr] train:63.4% val:66.9% test:67.6% maxVal:74.0% maxTest:73.5%
# [12/50] [Loss] train:1.686 val:0.750 test:0.762 [Accr] train:53.7% val:96.7% test:96.7% maxVal:97.1% maxTest:96.7%
# [07/50] [Loss] train:0.025(f:-0.141+r:0.050+k:0.001+l:0.115) val:-0.302 test:-0.310 [Accr] train:18.5% val:92.0% test:91.8% maxVal:92.0% maxTest:91.8%
# [12/50] [Loss] train:0.555 val:0.304 test:0.312 [Accr] train:76.2% val:94.2% test:93.9% maxVal:94.9% maxTest:94.5%
# [07/50] [Loss] train:-0.278(f:-0.469+r:0.075+k:0.001+l:0.115) val:-0.517 test:-0.516 [Accr] train:57.7% val:92.0% test:90.8% maxVal:92.0% maxTest:90.8%
# [07/50] [Loss] train:-0.219(f:-0.406+r:0.072+k:0.001+l:0.115) val:-0.426 test:-0.433 [Accr] train:50.8% val:83.1% test:84.3% maxVal:83.1% maxTest:84.3%
# [12/50] [Loss] train:0.623 val:0.389 test:0.390 [Accr] train:73.8% val:93.7% test:93.6% maxVal:94.2% maxTest:93.8%
# [07/50] [Loss] train:0.041(f:-0.116+r:0.041+k:0.001+l:0.115) val:-0.140 test:-0.152 [Accr] train:14.4% val:80.5% test:80.9% maxVal:80.5% maxTest:80.9%
# [07/50] [Loss] train:-0.239(f:-0.431+r:0.076+k:0.001+l:0.115) val:-0.575 test:-0.573 [Accr] train:53.5% val:97.2% test:97.2% maxVal:97.2% maxTest:97.2%
# [07/50] [Loss] train:-0.264(f:-0.453+r:0.074+k:0.001+l:0.115) val:-0.478 test:-0.475 [Accr] train:55.7% val:87.3% test:86.1% maxVal:87.7% maxTest:86.3%
# [07/50] [Loss] train:-0.236(f:-0.427+r:0.075+k:0.001+l:0.115) val:-0.497 test:-0.501 [Accr] train:53.5% val:96.2% test:95.9% maxVal:96.2% maxTest:95.9%
# [07/50] [Loss] train:-0.399(f:-0.595+r:0.080+k:0.001+l:0.115) val:-0.593 test:-0.592 [Accr] train:73.2% val:97.8% test:97.6% maxVal:97.8% maxTest:97.6%
# [13/50] [Loss] train:2.227 val:1.803 test:1.808 [Accr] train:19.5% val:76.0% test:74.8% maxVal:77.1% maxTest:77.1%
# [13/50] [Loss] train:0.755 val:0.784 test:0.788 [Accr] train:58.4% val:56.2% test:55.3% maxVal:61.0% maxTest:60.6%
# [13/50] [Loss] train:0.748 val:0.704 test:0.705 [Accr] train:59.3% val:66.8% test:65.3% maxVal:67.7% maxTest:67.6%
# [07/50] [Loss] train:-0.420(f:-0.616+r:0.080+k:0.001+l:0.115) val:-0.590 test:-0.588 [Accr] train:75.7% val:97.8% test:97.5% maxVal:97.8% maxTest:97.5%
# [14/50] [Loss] train:0.647 val:0.654 test:0.661 [Accr] train:64.3% val:67.7% test:68.2% maxVal:74.0% maxTest:73.5%
# [13/50] [Loss] train:1.679 val:0.704 test:0.725 [Accr] train:53.7% val:97.0% test:96.7% maxVal:97.1% maxTest:96.7%
# [13/50] [Loss] train:0.544 val:0.324 test:0.329 [Accr] train:76.3% val:94.1% test:93.4% maxVal:94.9% maxTest:94.5%
# [13/50] [Loss] train:0.621 val:0.373 test:0.375 [Accr] train:73.8% val:94.6% test:93.7% maxVal:94.6% maxTest:93.7%
# [14/50] [Loss] train:0.748 val:0.791 test:0.801 [Accr] train:59.1% val:54.2% test:53.9% maxVal:61.0% maxTest:60.6%
# [14/50] [Loss] train:2.221 val:1.790 test:1.797 [Accr] train:19.7% val:76.8% test:75.1% maxVal:77.1% maxTest:77.1%
# [08/50] [Loss] train:0.023(f:-0.142+r:0.049+k:0.001+l:0.114) val:-0.319 test:-0.324 [Accr] train:18.5% val:92.6% test:92.4% maxVal:92.6% maxTest:92.4%
# [08/50] [Loss] train:-0.285(f:-0.476+r:0.076+k:0.001+l:0.114) val:-0.531 test:-0.527 [Accr] train:57.9% val:92.6% test:91.6% maxVal:92.6% maxTest:91.6%
# [08/50] [Loss] train:-0.226(f:-0.414+r:0.073+k:0.001+l:0.114) val:-0.441 test:-0.445 [Accr] train:51.0% val:84.9% test:85.7% maxVal:84.9% maxTest:85.7%
# [14/50] [Loss] train:0.736 val:0.718 test:0.714 [Accr] train:60.4% val:65.0% test:64.5% maxVal:67.7% maxTest:67.6%
# [08/50] [Loss] train:0.039(f:-0.116+r:0.039+k:0.001+l:0.114) val:-0.140 test:-0.151 [Accr] train:14.5% val:82.3% test:82.2% maxVal:82.3% maxTest:82.2%
# [15/50] [Loss] train:0.643 val:0.689 test:0.697 [Accr] train:64.7% val:63.6% test:62.4% maxVal:74.0% maxTest:73.5%
# [08/50] [Loss] train:-0.268(f:-0.458+r:0.074+k:0.001+l:0.114) val:-0.490 test:-0.485 [Accr] train:55.9% val:88.2% test:86.7% maxVal:88.2% maxTest:86.7%
# [14/50] [Loss] train:1.675 val:0.756 test:0.773 [Accr] train:53.8% val:96.9% test:97.0% maxVal:97.1% maxTest:96.7%
# [08/50] [Loss] train:-0.244(f:-0.436+r:0.077+k:0.001+l:0.114) val:-0.585 test:-0.581 [Accr] train:53.7% val:97.5% test:97.5% maxVal:97.5% maxTest:97.5%
# [08/50] [Loss] train:-0.245(f:-0.435+r:0.074+k:0.001+l:0.114) val:-0.514 test:-0.515 [Accr] train:53.7% val:96.6% test:96.4% maxVal:96.6% maxTest:96.4%
# [14/50] [Loss] train:0.536 val:0.361 test:0.369 [Accr] train:76.2% val:92.0% test:91.1% maxVal:94.9% maxTest:94.5%
# [14/50] [Loss] train:0.608 val:0.388 test:0.386 [Accr] train:74.2% val:93.5% test:93.3% maxVal:94.6% maxTest:93.7%
# [08/50] [Loss] train:-0.408(f:-0.605+r:0.081+k:0.001+l:0.114) val:-0.604 test:-0.601 [Accr] train:73.4% val:97.9% test:97.8% maxVal:97.9% maxTest:97.8%
# [08/50] [Loss] train:-0.429(f:-0.626+r:0.082+k:0.001+l:0.114) val:-0.603 test:-0.599 [Accr] train:75.9% val:98.0% test:97.8% maxVal:98.0% maxTest:97.8%
# [15/50] [Loss] train:0.738 val:0.739 test:0.746 [Accr] train:59.7% val:61.1% test:60.8% maxVal:61.1% maxTest:60.8%
# [15/50] [Loss] train:2.217 val:1.798 test:1.805 [Accr] train:20.0% val:75.9% test:74.7% maxVal:77.1% maxTest:77.1%
# [15/50] [Loss] train:0.729 val:0.747 test:0.746 [Accr] train:60.9% val:60.7% test:60.5% maxVal:67.7% maxTest:67.6%
# [16/50] [Loss] train:0.640 val:0.694 test:0.705 [Accr] train:65.1% val:62.8% test:62.4% maxVal:74.0% maxTest:73.5%
# [15/50] [Loss] train:1.665 val:0.729 test:0.744 [Accr] train:53.9% val:97.0% test:97.0% maxVal:97.1% maxTest:96.7%
# [15/50] [Loss] train:0.602 val:0.369 test:0.367 [Accr] train:74.3% val:94.6% test:94.6% maxVal:94.6% maxTest:93.7%
# [15/50] [Loss] train:0.530 val:0.363 test:0.369 [Accr] train:76.6% val:92.1% test:91.1% maxVal:94.9% maxTest:94.5%
# [09/50] [Loss] train:0.021(f:-0.143+r:0.048+k:0.001+l:0.114) val:-0.324 test:-0.324 [Accr] train:18.6% val:93.0% test:92.9% maxVal:93.0% maxTest:92.9%
# [09/50] [Loss] train:-0.292(f:-0.484+r:0.076+k:0.001+l:0.114) val:-0.542 test:-0.536 [Accr] train:58.1% val:92.7% test:91.6% maxVal:92.7% maxTest:91.6%
# [09/50] [Loss] train:-0.231(f:-0.420+r:0.073+k:0.001+l:0.114) val:-0.457 test:-0.459 [Accr] train:51.4% val:87.2% test:87.6% maxVal:87.2% maxTest:87.6%
# [09/50] [Loss] train:0.037(f:-0.117+r:0.039+k:0.001+l:0.114) val:-0.156 test:-0.165 [Accr] train:14.6% val:82.9% test:82.5% maxVal:82.9% maxTest:82.5%
# [16/50] [Loss] train:0.725 val:0.766 test:0.770 [Accr] train:61.2% val:56.9% test:56.0% maxVal:61.1% maxTest:60.8%
# [16/50] [Loss] train:2.210 val:1.809 test:1.814 [Accr] train:20.3% val:75.1% test:73.6% maxVal:77.1% maxTest:77.1%
# [09/50] [Loss] train:-0.277(f:-0.467+r:0.075+k:0.001+l:0.114) val:-0.498 test:-0.489 [Accr] train:56.0% val:87.5% test:86.2% maxVal:88.2% maxTest:86.7%
# [09/50] [Loss] train:-0.249(f:-0.441+r:0.077+k:0.001+l:0.114) val:-0.598 test:-0.594 [Accr] train:53.8% val:97.7% test:97.7% maxVal:97.7% maxTest:97.7%
# [09/50] [Loss] train:-0.250(f:-0.441+r:0.075+k:0.001+l:0.114) val:-0.528 test:-0.528 [Accr] train:53.8% val:96.9% test:96.7% maxVal:96.9% maxTest:96.7%
# [16/50] [Loss] train:0.722 val:0.736 test:0.734 [Accr] train:61.4% val:61.0% test:60.8% maxVal:67.7% maxTest:67.6%
# [17/50] [Loss] train:0.630 val:0.706 test:0.711 [Accr] train:65.9% val:61.7% test:61.2% maxVal:74.0% maxTest:73.5%
# [09/50] [Loss] train:-0.416(f:-0.613+r:0.082+k:0.001+l:0.114) val:-0.617 test:-0.614 [Accr] train:73.5% val:98.2% test:98.0% maxVal:98.2% maxTest:98.0%
# [16/50] [Loss] train:1.659 val:0.720 test:0.733 [Accr] train:54.0% val:97.1% test:97.0% maxVal:97.1% maxTest:96.7%
# [09/50] [Loss] train:-0.437(f:-0.634+r:0.082+k:0.001+l:0.114) val:-0.615 test:-0.612 [Accr] train:76.0% val:98.2% test:98.0% maxVal:98.2% maxTest:98.0%
# [16/50] [Loss] train:0.594 val:0.362 test:0.362 [Accr] train:74.5% val:94.6% test:94.2% maxVal:94.6% maxTest:94.2%
# [16/50] [Loss] train:0.529 val:0.340 test:0.353 [Accr] train:76.5% val:92.6% test:91.5% maxVal:94.9% maxTest:94.5%
# [17/50] [Loss] train:0.722 val:0.800 test:0.800 [Accr] train:61.0% val:50.8% test:50.3% maxVal:61.1% maxTest:60.8%
# [17/50] [Loss] train:2.206 val:1.801 test:1.811 [Accr] train:20.6% val:73.4% test:72.2% maxVal:77.1% maxTest:77.1%
# [17/50] [Loss] train:0.712 val:0.710 test:0.709 [Accr] train:62.4% val:64.4% test:64.1% maxVal:67.7% maxTest:67.6%
# [10/50] [Loss] train:0.018(f:-0.144+r:0.047+k:0.001+l:0.114) val:-0.335 test:-0.337 [Accr] train:18.7% val:93.4% test:93.3% maxVal:93.4% maxTest:93.3%
# [18/50] [Loss] train:0.632 val:0.778 test:0.791 [Accr] train:65.3% val:53.7% test:53.0% maxVal:74.0% maxTest:73.5%
# [10/50] [Loss] train:-0.297(f:-0.489+r:0.076+k:0.001+l:0.114) val:-0.551 test:-0.550 [Accr] train:58.2% val:93.6% test:92.5% maxVal:93.6% maxTest:92.5%
# [10/50] [Loss] train:-0.237(f:-0.425+r:0.073+k:0.001+l:0.114) val:-0.461 test:-0.466 [Accr] train:51.5% val:88.3% test:88.3% maxVal:88.3% maxTest:88.3%
# [10/50] [Loss] train:0.035(f:-0.117+r:0.037+k:0.001+l:0.114) val:-0.149 test:-0.158 [Accr] train:14.7% val:83.0% test:82.9% maxVal:83.0% maxTest:82.9%
# [17/50] [Loss] train:1.655 val:0.714 test:0.733 [Accr] train:54.0% val:97.2% test:96.8% maxVal:97.2% maxTest:96.8%
# [10/50] [Loss] train:-0.283(f:-0.473+r:0.075+k:0.001+l:0.114) val:-0.507 test:-0.504 [Accr] train:56.2% val:88.2% test:86.6% maxVal:88.2% maxTest:86.6%
# [17/50] [Loss] train:0.590 val:0.374 test:0.371 [Accr] train:74.5% val:93.4% test:93.2% maxVal:94.6% maxTest:94.2%
# [10/50] [Loss] train:-0.256(f:-0.449+r:0.077+k:0.001+l:0.114) val:-0.607 test:-0.606 [Accr] train:53.9% val:98.0% test:97.8% maxVal:98.0% maxTest:97.8%
# [17/50] [Loss] train:0.518 val:0.346 test:0.350 [Accr] train:76.9% val:92.5% test:91.9% maxVal:94.9% maxTest:94.5%
# [10/50] [Loss] train:-0.253(f:-0.444+r:0.075+k:0.001+l:0.114) val:-0.529 test:-0.530 [Accr] train:53.9% val:97.3% test:97.0% maxVal:97.3% maxTest:97.0%
# [10/50] [Loss] train:-0.422(f:-0.620+r:0.083+k:0.001+l:0.114) val:-0.623 test:-0.622 [Accr] train:73.6% val:98.3% test:98.2% maxVal:98.3% maxTest:98.2%
# [18/50] [Loss] train:0.715 val:0.766 test:0.759 [Accr] train:61.6% val:56.4% test:57.2% maxVal:61.1% maxTest:60.8%
# [18/50] [Loss] train:2.201 val:1.792 test:1.802 [Accr] train:20.8% val:73.8% test:72.7% maxVal:77.1% maxTest:77.1%
# [18/50] [Loss] train:0.708 val:0.717 test:0.710 [Accr] train:62.5% val:62.8% test:63.2% maxVal:67.7% maxTest:67.6%
# [19/50] [Loss] train:0.624 val:0.709 test:0.720 [Accr] train:66.3% val:61.0% test:60.8% maxVal:74.0% maxTest:73.5%
# [10/50] [Loss] train:-0.443(f:-0.641+r:0.083+k:0.001+l:0.114) val:-0.620 test:-0.619 [Accr] train:76.2% val:98.3% test:98.1% maxVal:98.3% maxTest:98.1%
# [18/50] [Loss] train:1.647 val:0.730 test:0.745 [Accr] train:54.1% val:97.2% test:97.0% maxVal:97.2% maxTest:97.0%
# [18/50] [Loss] train:0.580 val:0.378 test:0.377 [Accr] train:74.9% val:94.0% test:93.8% maxVal:94.6% maxTest:94.2%
# [18/50] [Loss] train:0.515 val:0.378 test:0.386 [Accr] train:76.9% val:90.9% test:90.0% maxVal:94.9% maxTest:94.5%
# [11/50] [Loss] train:0.017(f:-0.145+r:0.046+k:0.001+l:0.114) val:-0.333 test:-0.340 [Accr] train:18.6% val:93.6% test:93.5% maxVal:93.6% maxTest:93.5%
# [11/50] [Loss] train:-0.304(f:-0.496+r:0.077+k:0.001+l:0.114) val:-0.556 test:-0.556 [Accr] train:58.4% val:93.6% test:92.9% maxVal:93.6% maxTest:92.5%
# [11/50] [Loss] train:-0.241(f:-0.430+r:0.073+k:0.001+l:0.114) val:-0.466 test:-0.472 [Accr] train:51.7% val:88.9% test:88.9% maxVal:88.9% maxTest:88.9%
# [19/50] [Loss] train:0.707 val:0.742 test:0.739 [Accr] train:62.4% val:59.8% test:60.3% maxVal:61.1% maxTest:60.8%
# [11/50] [Loss] train:0.033(f:-0.118+r:0.036+k:0.001+l:0.114) val:-0.149 test:-0.160 [Accr] train:14.7% val:82.8% test:82.9% maxVal:83.0% maxTest:82.9%
# [19/50] [Loss] train:2.196 val:1.789 test:1.797 [Accr] train:21.0% val:74.3% test:72.8% maxVal:77.1% maxTest:77.1%
# [19/50] [Loss] train:0.711 val:0.719 test:0.714 [Accr] train:62.3% val:62.6% test:62.6% maxVal:67.7% maxTest:67.6%
# [20/50] [Loss] train:0.616 val:0.668 test:0.684 [Accr] train:67.0% val:64.8% test:63.8% maxVal:74.0% maxTest:73.5%
# [11/50] [Loss] train:-0.289(f:-0.478+r:0.074+k:0.001+l:0.114) val:-0.510 test:-0.509 [Accr] train:56.5% val:88.3% test:86.8% maxVal:88.3% maxTest:86.8%
# [11/50] [Loss] train:-0.259(f:-0.452+r:0.077+k:0.001+l:0.114) val:-0.613 test:-0.613 [Accr] train:53.9% val:98.0% test:97.9% maxVal:98.0% maxTest:97.9%
# [11/50] [Loss] train:-0.260(f:-0.451+r:0.076+k:0.001+l:0.114) val:-0.539 test:-0.544 [Accr] train:54.0% val:97.5% test:97.3% maxVal:97.5% maxTest:97.3%
# [19/50] [Loss] train:1.640 val:0.732 test:0.748 [Accr] train:54.1% val:97.1% test:97.0% maxVal:97.2% maxTest:97.0%
# [11/50] [Loss] train:-0.428(f:-0.626+r:0.083+k:0.001+l:0.114) val:-0.629 test:-0.630 [Accr] train:73.7% val:98.4% test:98.3% maxVal:98.4% maxTest:98.3%
# [19/50] [Loss] train:0.577 val:0.379 test:0.375 [Accr] train:75.0% val:93.7% test:93.3% maxVal:94.6% maxTest:94.2%
# [19/50] [Loss] train:0.512 val:0.325 test:0.332 [Accr] train:77.2% val:93.2% test:92.4% maxVal:94.9% maxTest:94.5%
# [11/50] [Loss] train:-0.449(f:-0.647+r:0.083+k:0.001+l:0.114) val:-0.626 test:-0.627 [Accr] train:76.2% val:98.4% test:98.4% maxVal:98.4% maxTest:98.4%
# [20/50] [Loss] train:0.700 val:0.765 test:0.759 [Accr] train:63.2% val:57.1% test:57.7% maxVal:61.1% maxTest:60.8%
# [20/50] [Loss] train:2.191 val:1.808 test:1.817 [Accr] train:21.4% val:71.5% test:70.7% maxVal:77.1% maxTest:77.1%
# [20/50] [Loss] train:0.705 val:0.735 test:0.730 [Accr] train:62.4% val:61.3% test:62.1% maxVal:67.7% maxTest:67.6%
# [21/50] [Loss] train:0.620 val:0.559 test:0.564 [Accr] train:66.4% val:76.7% test:76.2% maxVal:76.7% maxTest:76.2%
# [12/50] [Loss] train:0.014(f:-0.146+r:0.046+k:0.001+l:0.114) val:-0.341 test:-0.346 [Accr] train:18.8% val:93.9% test:93.6% maxVal:93.9% maxTest:93.6%
# [12/50] [Loss] train:-0.307(f:-0.499+r:0.077+k:0.001+l:0.114) val:-0.565 test:-0.561 [Accr] train:58.5% val:94.0% test:93.2% maxVal:94.0% maxTest:93.2%
# [12/50] [Loss] train:-0.247(f:-0.435+r:0.073+k:0.001+l:0.114) val:-0.480 test:-0.483 [Accr] train:51.8% val:90.0% test:89.7% maxVal:90.0% maxTest:89.7%
# [20/50] [Loss] train:1.634 val:0.718 test:0.734 [Accr] train:54.1% val:97.1% test:96.9% maxVal:97.2% maxTest:97.0%
# [12/50] [Loss] train:0.032(f:-0.118+r:0.035+k:0.001+l:0.114) val:-0.147 test:-0.158 [Accr] train:14.8% val:83.6% test:84.1% maxVal:83.6% maxTest:84.1%
# [20/50] [Loss] train:0.568 val:0.374 test:0.370 [Accr] train:75.2% val:93.9% test:93.8% maxVal:94.6% maxTest:94.2%
# [20/50] [Loss] train:0.505 val:0.372 test:0.381 [Accr] train:77.4% val:91.5% test:90.6% maxVal:94.9% maxTest:94.5%
# [12/50] [Loss] train:-0.292(f:-0.481+r:0.075+k:0.001+l:0.114) val:-0.519 test:-0.513 [Accr] train:56.6% val:88.5% test:87.0% maxVal:88.5% maxTest:87.0%
# [21/50] [Loss] train:0.695 val:0.766 test:0.761 [Accr] train:63.7% val:55.6% test:56.6% maxVal:61.1% maxTest:60.8%
# [12/50] [Loss] train:-0.264(f:-0.458+r:0.078+k:0.001+l:0.114) val:-0.624 test:-0.623 [Accr] train:54.0% val:98.2% test:98.1% maxVal:98.2% maxTest:98.1%
# [21/50] [Loss] train:2.184 val:1.774 test:1.780 [Accr] train:21.3% val:73.5% test:72.1% maxVal:77.1% maxTest:77.1%
# [12/50] [Loss] train:-0.265(f:-0.456+r:0.076+k:0.001+l:0.114) val:-0.552 test:-0.553 [Accr] train:54.1% val:97.7% test:97.5% maxVal:97.7% maxTest:97.5%
# [21/50] [Loss] train:0.689 val:0.735 test:0.727 [Accr] train:64.3% val:59.4% test:60.5% maxVal:67.7% maxTest:67.6%
# [22/50] [Loss] train:0.609 val:0.635 test:0.635 [Accr] train:67.7% val:68.6% test:68.8% maxVal:76.7% maxTest:76.2%
# [12/50] [Loss] train:-0.435(f:-0.634+r:0.084+k:0.001+l:0.114) val:-0.639 test:-0.639 [Accr] train:73.8% val:98.6% test:98.4% maxVal:98.6% maxTest:98.4%
# [21/50] [Loss] train:1.626 val:0.684 test:0.702 [Accr] train:54.2% val:97.2% test:97.0% maxVal:97.2% maxTest:97.0%
# [12/50] [Loss] train:-0.455(f:-0.653+r:0.084+k:0.001+l:0.114) val:-0.635 test:-0.635 [Accr] train:76.3% val:98.5% test:98.4% maxVal:98.5% maxTest:98.4%
# [21/50] [Loss] train:0.563 val:0.371 test:0.370 [Accr] train:75.3% val:94.1% test:93.8% maxVal:94.6% maxTest:94.2%
# [21/50] [Loss] train:0.501 val:0.292 test:0.297 [Accr] train:77.6% val:95.0% test:94.4% maxVal:95.0% maxTest:94.4%
# [22/50] [Loss] train:0.688 val:0.733 test:0.734 [Accr] train:64.2% val:60.0% test:58.9% maxVal:61.1% maxTest:60.8%
# [13/50] [Loss] train:0.013(f:-0.146+r:0.044+k:0.001+l:0.114) val:-0.337 test:-0.343 [Accr] train:18.8% val:94.3% test:94.2% maxVal:94.3% maxTest:94.2%
# [22/50] [Loss] train:2.183 val:1.795 test:1.802 [Accr] train:21.5% val:68.6% test:67.9% maxVal:77.1% maxTest:77.1%
# [13/50] [Loss] train:-0.311(f:-0.503+r:0.077+k:0.001+l:0.114) val:-0.571 test:-0.567 [Accr] train:58.7% val:94.2% test:93.5% maxVal:94.2% maxTest:93.5%
# [13/50] [Loss] train:-0.251(f:-0.439+r:0.074+k:0.001+l:0.114) val:-0.488 test:-0.492 [Accr] train:51.9% val:90.7% test:90.6% maxVal:90.7% maxTest:90.6%
# [22/50] [Loss] train:0.687 val:0.674 test:0.672 [Accr] train:64.0% val:68.7% test:68.2% maxVal:68.7% maxTest:68.2%
# [23/50] [Loss] train:0.599 val:0.669 test:0.672 [Accr] train:68.7% val:65.6% test:65.3% maxVal:76.7% maxTest:76.2%
# [13/50] [Loss] train:0.029(f:-0.119+r:0.033+k:0.001+l:0.114) val:-0.155 test:-0.167 [Accr] train:14.9% val:84.4% test:83.8% maxVal:84.4% maxTest:83.8%
# [13/50] [Loss] train:-0.296(f:-0.486+r:0.075+k:0.001+l:0.114) val:-0.522 test:-0.517 [Accr] train:56.8% val:88.4% test:86.9% maxVal:88.5% maxTest:87.0%
# [13/50] [Loss] train:-0.268(f:-0.461+r:0.077+k:0.001+l:0.114) val:-0.631 test:-0.629 [Accr] train:54.1% val:98.3% test:98.3% maxVal:98.3% maxTest:98.3%
# [22/50] [Loss] train:1.621 val:0.714 test:0.732 [Accr] train:54.3% val:97.3% test:96.6% maxVal:97.3% maxTest:96.6%
# [22/50] [Loss] train:0.560 val:0.366 test:0.360 [Accr] train:75.6% val:93.8% test:94.1% maxVal:94.6% maxTest:94.2%
# [13/50] [Loss] train:-0.269(f:-0.460+r:0.076+k:0.001+l:0.114) val:-0.561 test:-0.562 [Accr] train:54.2% val:97.8% test:97.5% maxVal:97.8% maxTest:97.5%
# [22/50] [Loss] train:0.499 val:0.349 test:0.352 [Accr] train:77.7% val:91.2% test:91.0% maxVal:95.0% maxTest:94.4%
# [13/50] [Loss] train:-0.440(f:-0.638+r:0.084+k:0.001+l:0.114) val:-0.648 test:-0.647 [Accr] train:73.9% val:98.6% test:98.5% maxVal:98.6% maxTest:98.5%
# [23/50] [Loss] train:0.685 val:0.779 test:0.771 [Accr] train:64.4% val:54.0% test:54.5% maxVal:61.1% maxTest:60.8%
# [23/50] [Loss] train:2.173 val:1.791 test:1.797 [Accr] train:22.0% val:70.4% test:69.8% maxVal:77.1% maxTest:77.1%
# [23/50] [Loss] train:0.681 val:0.741 test:0.735 [Accr] train:64.8% val:59.6% test:60.2% maxVal:68.7% maxTest:68.2%
# [24/50] [Loss] train:0.592 val:0.667 test:0.666 [Accr] train:69.2% val:63.9% test:64.6% maxVal:76.7% maxTest:76.2%
# [13/50] [Loss] train:-0.460(f:-0.660+r:0.085+k:0.001+l:0.114) val:-0.644 test:-0.643 [Accr] train:76.4% val:98.5% test:98.6% maxVal:98.5% maxTest:98.6%
# [14/50] [Loss] train:0.011(f:-0.147+r:0.044+k:0.001+l:0.113) val:-0.348 test:-0.351 [Accr] train:18.8% val:94.3% test:94.3% maxVal:94.3% maxTest:94.3%
# [23/50] [Loss] train:1.618 val:0.664 test:0.682 [Accr] train:54.2% val:97.4% test:97.0% maxVal:97.4% maxTest:97.0%
# [14/50] [Loss] train:-0.316(f:-0.506+r:0.076+k:0.001+l:0.113) val:-0.581 test:-0.577 [Accr] train:58.8% val:94.9% test:94.2% maxVal:94.9% maxTest:94.2%
# [14/50] [Loss] train:-0.253(f:-0.442+r:0.074+k:0.001+l:0.113) val:-0.493 test:-0.495 [Accr] train:52.0% val:91.4% test:91.0% maxVal:91.4% maxTest:91.0%
# [23/50] [Loss] train:0.552 val:0.343 test:0.339 [Accr] train:75.6% val:94.9% test:94.9% maxVal:94.9% maxTest:94.9%
# [14/50] [Loss] train:0.027(f:-0.119+r:0.032+k:0.001+l:0.113) val:-0.158 test:-0.164 [Accr] train:14.9% val:84.1% test:83.5% maxVal:84.4% maxTest:83.8%
# [23/50] [Loss] train:0.492 val:0.314 test:0.319 [Accr] train:77.9% val:93.5% test:93.0% maxVal:95.0% maxTest:94.4%
# [24/50] [Loss] train:0.681 val:0.780 test:0.774 [Accr] train:65.0% val:54.5% test:55.2% maxVal:61.1% maxTest:60.8%
# [24/50] [Loss] train:2.172 val:1.803 test:1.812 [Accr] train:22.1% val:66.4% test:65.2% maxVal:77.1% maxTest:77.1%
# [14/50] [Loss] train:-0.300(f:-0.488+r:0.074+k:0.001+l:0.113) val:-0.533 test:-0.527 [Accr] train:56.9% val:89.3% test:87.9% maxVal:89.3% maxTest:87.9%
# [24/50] [Loss] train:0.675 val:0.711 test:0.704 [Accr] train:65.0% val:63.4% test:63.8% maxVal:68.7% maxTest:68.2%
# [25/50] [Loss] train:0.594 val:0.777 test:0.777 [Accr] train:69.3% val:52.0% test:52.2% maxVal:76.7% maxTest:76.2%
# [14/50] [Loss] train:-0.272(f:-0.464+r:0.078+k:0.001+l:0.113) val:-0.640 test:-0.636 [Accr] train:54.1% val:98.3% test:98.3% maxVal:98.3% maxTest:98.3%
# [14/50] [Loss] train:-0.272(f:-0.462+r:0.076+k:0.001+l:0.113) val:-0.565 test:-0.564 [Accr] train:54.2% val:97.8% test:97.7% maxVal:97.8% maxTest:97.7%
# [14/50] [Loss] train:-0.444(f:-0.643+r:0.085+k:0.001+l:0.113) val:-0.653 test:-0.652 [Accr] train:73.9% val:98.6% test:98.6% maxVal:98.6% maxTest:98.6%
# [24/50] [Loss] train:1.607 val:0.704 test:0.718 [Accr] train:54.3% val:97.3% test:97.0% maxVal:97.4% maxTest:97.0%
# [24/50] [Loss] train:0.550 val:0.351 test:0.349 [Accr] train:75.8% val:94.1% test:94.0% maxVal:94.9% maxTest:94.9%
# [25/50] [Loss] train:0.670 val:0.760 test:0.759 [Accr] train:65.9% val:57.1% test:56.2% maxVal:61.1% maxTest:60.8%
# [24/50] [Loss] train:0.485 val:0.363 test:0.367 [Accr] train:78.4% val:91.5% test:91.1% maxVal:95.0% maxTest:94.4%
# [14/50] [Loss] train:-0.467(f:-0.666+r:0.085+k:0.001+l:0.113) val:-0.651 test:-0.650 [Accr] train:76.5% val:98.6% test:98.6% maxVal:98.6% maxTest:98.6%
# [25/50] [Loss] train:2.163 val:1.788 test:1.796 [Accr] train:22.5% val:69.9% test:68.7% maxVal:77.1% maxTest:77.1%
# [15/50] [Loss] train:0.010(f:-0.147+r:0.042+k:0.001+l:0.113) val:-0.354 test:-0.356 [Accr] train:18.8% val:94.5% test:94.5% maxVal:94.5% maxTest:94.5%
# [26/50] [Loss] train:0.583 val:0.638 test:0.647 [Accr] train:69.6% val:68.5% test:68.6% maxVal:76.7% maxTest:76.2%
# [25/50] [Loss] train:0.668 val:0.723 test:0.718 [Accr] train:66.1% val:61.5% test:61.7% maxVal:68.7% maxTest:68.2%
# [15/50] [Loss] train:-0.320(f:-0.511+r:0.077+k:0.001+l:0.113) val:-0.584 test:-0.580 [Accr] train:58.9% val:94.8% test:94.2% maxVal:94.9% maxTest:94.2%
# [15/50] [Loss] train:-0.259(f:-0.447+r:0.074+k:0.001+l:0.113) val:-0.502 test:-0.503 [Accr] train:52.2% val:91.3% test:90.8% maxVal:91.4% maxTest:91.0%
# [15/50] [Loss] train:0.026(f:-0.120+r:0.031+k:0.001+l:0.113) val:-0.157 test:-0.162 [Accr] train:15.0% val:83.5% test:83.5% maxVal:84.4% maxTest:83.8%
# [25/50] [Loss] train:1.604 val:0.704 test:0.719 [Accr] train:54.3% val:97.4% test:96.9% maxVal:97.4% maxTest:96.9%
# [15/50] [Loss] train:-0.304(f:-0.493+r:0.074+k:0.001+l:0.113) val:-0.532 test:-0.523 [Accr] train:57.0% val:88.6% test:87.2% maxVal:89.3% maxTest:87.9%
# [25/50] [Loss] train:0.543 val:0.367 test:0.362 [Accr] train:76.0% val:94.0% test:93.6% maxVal:94.9% maxTest:94.9%
# [15/50] [Loss] train:-0.276(f:-0.469+r:0.078+k:0.001+l:0.113) val:-0.647 test:-0.645 [Accr] train:54.2% val:98.4% test:98.5% maxVal:98.4% maxTest:98.5%
# [26/50] [Loss] train:0.665 val:0.758 test:0.751 [Accr] train:66.3% val:56.1% test:56.8% maxVal:61.1% maxTest:60.8%
# [25/50] [Loss] train:0.487 val:0.410 test:0.422 [Accr] train:78.4% val:87.9% test:87.1% maxVal:95.0% maxTest:94.4%
# [26/50] [Loss] train:2.157 val:1.780 test:1.785 [Accr] train:22.8% val:69.5% test:69.2% maxVal:77.1% maxTest:77.1%
# [15/50] [Loss] train:-0.276(f:-0.466+r:0.076+k:0.001+l:0.113) val:-0.572 test:-0.572 [Accr] train:54.3% val:97.9% test:97.7% maxVal:97.9% maxTest:97.7%
# [27/50] [Loss] train:0.578 val:0.666 test:0.668 [Accr] train:70.5% val:64.2% test:64.4% maxVal:76.7% maxTest:76.2%
# [26/50] [Loss] train:0.660 val:0.734 test:0.731 [Accr] train:67.0% val:59.2% test:59.3% maxVal:68.7% maxTest:68.2%
# [15/50] [Loss] train:-0.449(f:-0.648+r:0.084+k:0.001+l:0.113) val:-0.659 test:-0.658 [Accr] train:74.0% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# ...
# [44/50] [Loss] train:-0.046(f:-0.171+r:0.016+k:0.001+l:0.109) val:-0.354 test:-0.361 [Accr] train:19.9% val:95.0% test:95.6% maxVal:95.4% maxTest:95.6%
# [42/50] [Loss] train:-0.341(f:-0.507+r:0.056+k:0.001+l:0.109) val:-0.739 test:-0.739 [Accr] train:54.8% val:99.0% test:99.0% maxVal:99.0% maxTest:99.0%
# [45/50] [Loss] train:-0.344(f:-0.511+r:0.057+k:0.001+l:0.109) val:-0.515 test:-0.515 [Accr] train:56.8% val:89.9% test:89.0% maxVal:93.7% maxTest:92.7%
# [41/50] [Loss] train:-0.547(f:-0.733+r:0.075+k:0.001+l:0.109) val:-0.750 test:-0.749 [Accr] train:77.3% val:99.2% test:99.2% maxVal:99.2% maxTest:99.2%
# [44/50] [Loss] train:-0.407(f:-0.578+r:0.061+k:0.001+l:0.109) val:-0.561 test:-0.560 [Accr] train:64.2% val:88.3% test:87.7% maxVal:95.2% maxTest:94.8%
# [42/50] [Loss] train:-0.348(f:-0.518+r:0.060+k:0.001+l:0.109) val:-0.638 test:-0.635 [Accr] train:55.5% val:97.9% test:97.5% maxVal:98.3% maxTest:98.0%
# [36/50] [Loss] train:-0.514(f:-0.701+r:0.076+k:0.001+l:0.110) val:-0.738 test:-0.737 [Accr] train:74.7% val:99.1% test:99.2% maxVal:99.2% maxTest:99.1%
# [45/50] [Loss] train:-0.034(f:-0.155+r:0.011+k:0.001+l:0.109) val:-0.163 test:-0.163 [Accr] train:20.5% val:70.6% test:69.0% maxVal:84.4% maxTest:83.8%
# [45/50] [Loss] train:-0.052(f:-0.176+r:0.014+k:0.001+l:0.109) val:-0.384 test:-0.382 [Accr] train:19.9% val:94.4% test:95.6% maxVal:95.4% maxTest:95.6%
# [43/50] [Loss] train:-0.343(f:-0.508+r:0.054+k:0.001+l:0.109) val:-0.742 test:-0.743 [Accr] train:54.8% val:99.1% test:99.1% maxVal:99.1% maxTest:99.1%
# [46/50] [Loss] train:-0.346(f:-0.512+r:0.057+k:0.001+l:0.109) val:-0.520 test:-0.520 [Accr] train:56.9% val:90.0% test:89.3% maxVal:93.7% maxTest:92.7%
# [42/50] [Loss] train:-0.549(f:-0.734+r:0.074+k:0.001+l:0.109) val:-0.753 test:-0.752 [Accr] train:77.3% val:99.2% test:99.2% maxVal:99.2% maxTest:99.2%
# [45/50] [Loss] train:-0.409(f:-0.580+r:0.061+k:0.001+l:0.109) val:-0.562 test:-0.558 [Accr] train:64.5% val:87.7% test:87.1% maxVal:95.2% maxTest:94.8%
# [37/50] [Loss] train:-0.384(f:-0.559+r:0.064+k:0.001+l:0.110) val:-0.493 test:-0.494 [Accr] train:62.6% val:80.2% test:79.6% maxVal:89.3% maxTest:87.9%
# [43/50] [Loss] train:-0.350(f:-0.520+r:0.059+k:0.001+l:0.109) val:-0.639 test:-0.638 [Accr] train:55.5% val:97.9% test:97.3% maxVal:98.3% maxTest:98.0%
# [46/50] [Loss] train:-0.038(f:-0.157+r:0.009+k:0.001+l:0.109) val:-0.156 test:-0.157 [Accr] train:21.1% val:68.0% test:66.5% maxVal:84.4% maxTest:83.8%
# [46/50] [Loss] train:-0.051(f:-0.174+r:0.013+k:0.001+l:0.109) val:-0.363 test:-0.363 [Accr] train:20.0% val:94.6% test:95.5% maxVal:95.4% maxTest:95.6%
# [44/50] [Loss] train:-0.346(f:-0.510+r:0.053+k:0.001+l:0.109) val:-0.746 test:-0.746 [Accr] train:54.8% val:99.2% test:99.1% maxVal:99.2% maxTest:99.1%
# [47/50] [Loss] train:-0.347(f:-0.513+r:0.055+k:0.001+l:0.109) val:-0.510 test:-0.508 [Accr] train:57.2% val:89.0% test:88.4% maxVal:93.7% maxTest:92.7%
# [46/50] [Loss] train:-0.412(f:-0.581+r:0.059+k:0.001+l:0.109) val:-0.569 test:-0.567 [Accr] train:64.6% val:89.1% test:88.5% maxVal:95.2% maxTest:94.8%
# [43/50] [Loss] train:-0.554(f:-0.737+r:0.073+k:0.001+l:0.109) val:-0.757 test:-0.755 [Accr] train:77.3% val:99.2% test:99.1% maxVal:99.2% maxTest:99.2%
# [44/50] [Loss] train:-0.353(f:-0.522+r:0.058+k:0.001+l:0.109) val:-0.644 test:-0.644 [Accr] train:55.5% val:98.0% test:97.6% maxVal:98.3% maxTest:98.0%
# [47/50] [Loss] train:-0.038(f:-0.158+r:0.010+k:0.001+l:0.108) val:-0.151 test:-0.151 [Accr] train:21.5% val:69.7% test:68.0% maxVal:84.4% maxTest:83.8%
# [47/50] [Loss] train:-0.059(f:-0.181+r:0.012+k:0.001+l:0.108) val:-0.398 test:-0.401 [Accr] train:20.0% val:94.6% test:95.5% maxVal:95.4% maxTest:95.6%
# [37/50] [Loss] train:-0.517(f:-0.703+r:0.074+k:0.001+l:0.110) val:-0.743 test:-0.743 [Accr] train:74.7% val:99.1% test:99.2% maxVal:99.2% maxTest:99.1%
# [45/50] [Loss] train:-0.347(f:-0.509+r:0.051+k:0.001+l:0.109) val:-0.743 test:-0.745 [Accr] train:54.8% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# [48/50] [Loss] train:-0.352(f:-0.517+r:0.055+k:0.001+l:0.108) val:-0.509 test:-0.507 [Accr] train:57.7% val:88.2% test:87.9% maxVal:93.7% maxTest:92.7%
# [47/50] [Loss] train:-0.417(f:-0.586+r:0.060+k:0.001+l:0.109) val:-0.561 test:-0.560 [Accr] train:65.2% val:87.9% test:87.3% maxVal:95.2% maxTest:94.8%
# [44/50] [Loss] train:-0.556(f:-0.738+r:0.072+k:0.001+l:0.109) val:-0.759 test:-0.757 [Accr] train:77.3% val:99.2% test:99.2% maxVal:99.2% maxTest:99.2%
# [45/50] [Loss] train:-0.356(f:-0.523+r:0.057+k:0.001+l:0.109) val:-0.647 test:-0.649 [Accr] train:55.5% val:98.1% test:97.6% maxVal:98.3% maxTest:98.0%
# [38/50] [Loss] train:-0.384(f:-0.558+r:0.062+k:0.001+l:0.110) val:-0.501 test:-0.497 [Accr] train:63.0% val:82.2% test:81.1% maxVal:89.3% maxTest:87.9%
# [48/50] [Loss] train:-0.041(f:-0.159+r:0.009+k:0.001+l:0.108) val:-0.159 test:-0.161 [Accr] train:21.4% val:68.4% test:67.1% maxVal:84.4% maxTest:83.8%
# [48/50] [Loss] train:-0.061(f:-0.182+r:0.012+k:0.001+l:0.108) val:-0.390 test:-0.393 [Accr] train:20.1% val:94.5% test:95.6% maxVal:95.4% maxTest:95.6%
# [46/50] [Loss] train:-0.351(f:-0.510+r:0.050+k:0.001+l:0.109) val:-0.750 test:-0.749 [Accr] train:54.8% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# [49/50] [Loss] train:-0.353(f:-0.518+r:0.055+k:0.001+l:0.108) val:-0.506 test:-0.507 [Accr] train:58.0% val:86.4% test:86.1% maxVal:93.7% maxTest:92.7%
# [48/50] [Loss] train:-0.418(f:-0.585+r:0.057+k:0.001+l:0.108) val:-0.561 test:-0.558 [Accr] train:65.4% val:88.4% test:87.7% maxVal:95.2% maxTest:94.8%
# [45/50] [Loss] train:-0.556(f:-0.738+r:0.071+k:0.001+l:0.109) val:-0.759 test:-0.759 [Accr] train:77.3% val:99.2% test:99.1% maxVal:99.2% maxTest:99.2%
# [46/50] [Loss] train:-0.359(f:-0.524+r:0.056+k:0.001+l:0.109) val:-0.640 test:-0.640 [Accr] train:55.6% val:97.9% test:97.3% maxVal:98.3% maxTest:98.0%
# [49/50] [Loss] train:-0.042(f:-0.160+r:0.009+k:0.001+l:0.108) val:-0.148 test:-0.148 [Accr] train:22.0% val:67.0% test:65.4% maxVal:84.4% maxTest:83.8%
# [49/50] [Loss] train:-0.059(f:-0.180+r:0.012+k:0.001+l:0.108) val:-0.373 test:-0.371 [Accr] train:20.1% val:94.7% test:95.5% maxVal:95.4% maxTest:95.6%
# [50/50] [Loss] train:-0.357(f:-0.521+r:0.055+k:0.001+l:0.108) val:-0.511 test:-0.509 [Accr] train:58.2% val:88.9% test:88.3% maxVal:93.7% maxTest:92.7%
# Training finished.
# [Worker_06] Done.
# [47/50] [Loss] train:-0.351(f:-0.510+r:0.049+k:0.001+l:0.109) val:-0.749 test:-0.750 [Accr] train:54.9% val:99.2% test:99.1% maxVal:99.2% maxTest:99.1%
# [38/50] [Loss] train:-0.520(f:-0.704+r:0.074+k:0.001+l:0.110) val:-0.744 test:-0.745 [Accr] train:74.7% val:99.2% test:99.1% maxVal:99.2% maxTest:99.1%
# [49/50] [Loss] train:-0.423(f:-0.590+r:0.058+k:0.001+l:0.108) val:-0.562 test:-0.557 [Accr] train:65.8% val:87.8% test:86.9% maxVal:95.2% maxTest:94.8%
# [46/50] [Loss] train:-0.557(f:-0.737+r:0.070+k:0.001+l:0.109) val:-0.760 test:-0.758 [Accr] train:77.4% val:99.2% test:99.1% maxVal:99.2% maxTest:99.2%
# [47/50] [Loss] train:-0.361(f:-0.526+r:0.055+k:0.001+l:0.109) val:-0.645 test:-0.648 [Accr] train:55.7% val:97.8% test:97.5% maxVal:98.3% maxTest:98.0%
# [39/50] [Loss] train:-0.389(f:-0.561+r:0.061+k:0.001+l:0.110) val:-0.501 test:-0.496 [Accr] train:63.5% val:81.6% test:80.7% maxVal:89.3% maxTest:87.9%
# [50/50] [Loss] train:-0.042(f:-0.161+r:0.010+k:0.001+l:0.108) val:-0.144 test:-0.143 [Accr] train:22.2% val:66.4% test:64.8% maxVal:84.4% maxTest:83.8%
# Training finished.
# [Worker_07] Done.
# [50/50] [Loss] train:-0.064(f:-0.185+r:0.011+k:0.001+l:0.108) val:-0.389 test:-0.391 [Accr] train:20.1% val:94.3% test:95.3% maxVal:95.4% maxTest:95.6%
# Training finished.
# [Worker_04] Done.
# [48/50] [Loss] train:-0.355(f:-0.512+r:0.048+k:0.001+l:0.108) val:-0.755 test:-0.755 [Accr] train:54.9% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# [50/50] [Loss] train:-0.427(f:-0.593+r:0.056+k:0.001+l:0.108) val:-0.586 test:-0.582 [Accr] train:65.6% val:90.0% test:89.5% maxVal:95.2% maxTest:94.8%
# Training finished.
# [Worker_05] Done.
# [47/50] [Loss] train:-0.560(f:-0.738+r:0.069+k:0.001+l:0.109) val:-0.761 test:-0.761 [Accr] train:77.4% val:99.2% test:99.2% maxVal:99.2% maxTest:99.2%
# [48/50] [Loss] train:-0.362(f:-0.526+r:0.055+k:0.001+l:0.108) val:-0.639 test:-0.639 [Accr] train:55.7% val:97.9% test:97.4% maxVal:98.3% maxTest:98.0%
# [49/50] [Loss] train:-0.358(f:-0.513+r:0.046+k:0.001+l:0.108) val:-0.758 test:-0.759 [Accr] train:54.9% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# [39/50] [Loss] train:-0.521(f:-0.705+r:0.073+k:0.001+l:0.110) val:-0.746 test:-0.746 [Accr] train:74.7% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# [48/50] [Loss] train:-0.561(f:-0.738+r:0.068+k:0.001+l:0.108) val:-0.765 test:-0.764 [Accr] train:77.4% val:99.3% test:99.2% maxVal:99.3% maxTest:99.2%
# [49/50] [Loss] train:-0.365(f:-0.527+r:0.053+k:0.001+l:0.108) val:-0.647 test:-0.646 [Accr] train:55.7% val:97.9% test:97.4% maxVal:98.3% maxTest:98.0%
# [40/50] [Loss] train:-0.392(f:-0.562+r:0.060+k:0.001+l:0.110) val:-0.503 test:-0.504 [Accr] train:63.5% val:82.2% test:81.5% maxVal:89.3% maxTest:87.9%
# [50/50] [Loss] train:-0.358(f:-0.512+r:0.044+k:0.001+l:0.108) val:-0.757 test:-0.758 [Accr] train:54.9% val:99.1% test:99.1% maxVal:99.2% maxTest:99.1%
# Training finished.
# Extracting ../data/train-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Text name: ../res/res_mnist_b_err95_basic_cnn.txt
# [49/50] [Loss] train:-0.564(f:-0.740+r:0.066+k:0.001+l:0.108) val:-0.768 test:-0.766 [Accr] train:77.4% val:99.2% test:99.1% maxVal:99.3% maxTest:99.2%
# [50/50] [Loss] train:-0.366(f:-0.527+r:0.052+k:0.001+l:0.108) val:-0.636 test:-0.638 [Accr] train:55.9% val:97.6% test:97.2% maxVal:98.3% maxTest:98.0%
# Training finished.
# [Worker_03] Done.
# [00/50] [Loss] train:0.950 val:1.060 test:1.057 [Accr] train:54.5% val:51.0% test:51.0% maxVal:51.0% maxTest:51.0%
# [40/50] [Loss] train:-0.523(f:-0.706+r:0.072+k:0.001+l:0.110) val:-0.749 test:-0.749 [Accr] train:74.7% val:99.2% test:99.2% maxVal:99.2% maxTest:99.1%
# [50/50] [Loss] train:-0.565(f:-0.740+r:0.066+k:0.001+l:0.108) val:-0.769 test:-0.767 [Accr] train:77.4% val:99.3% test:99.2% maxVal:99.3% maxTest:99.2%
# Training finished.
# [Worker_02] Done.
# [01/50] [Loss] train:0.848 val:0.958 test:0.971 [Accr] train:55.6% val:51.7% test:50.9% maxVal:51.7% maxTest:50.9%
# [41/50] [Loss] train:-0.398(f:-0.569+r:0.060+k:0.001+l:0.109) val:-0.503 test:-0.503 [Accr] train:64.3% val:82.3% test:81.2% maxVal:89.3% maxTest:87.9%
# [02/50] [Loss] train:0.801 val:0.900 test:0.911 [Accr] train:56.6% val:53.1% test:52.3% maxVal:53.1% maxTest:52.3%
# [03/50] [Loss] train:0.777 val:0.914 test:0.923 [Accr] train:56.9% val:49.5% test:49.0% maxVal:53.1% maxTest:52.3%
# [04/50] [Loss] train:0.751 val:0.838 test:0.855 [Accr] train:57.9% val:54.7% test:53.7% maxVal:54.7% maxTest:53.7%
# [41/50] [Loss] train:-0.526(f:-0.706+r:0.070+k:0.001+l:0.109) val:-0.751 test:-0.750 [Accr] train:74.8% val:99.2% test:99.2% maxVal:99.2% maxTest:99.1%
# [42/50] [Loss] train:-0.402(f:-0.572+r:0.060+k:0.001+l:0.109) val:-0.485 test:-0.482 [Accr] train:64.9% val:79.4% test:78.0% maxVal:89.3% maxTest:87.9%
# [05/50] [Loss] train:0.734 val:0.757 test:0.768 [Accr] train:58.9% val:62.7% test:61.2% maxVal:62.7% maxTest:61.2%
# [06/50] [Loss] train:0.727 val:0.806 test:0.828 [Accr] train:59.1% val:57.3% test:55.1% maxVal:62.7% maxTest:61.2%
# [07/50] [Loss] train:0.712 val:0.791 test:0.807 [Accr] train:59.6% val:55.8% test:54.2% maxVal:62.7% maxTest:61.2%
# [42/50] [Loss] train:-0.528(f:-0.708+r:0.070+k:0.001+l:0.109) val:-0.755 test:-0.754 [Accr] train:74.7% val:99.2% test:99.1% maxVal:99.2% maxTest:99.1%
# [08/50] [Loss] train:0.707 val:0.671 test:0.677 [Accr] train:60.3% val:68.9% test:68.2% maxVal:68.9% maxTest:68.2%
# [43/50] [Loss] train:-0.406(f:-0.576+r:0.059+k:0.001+l:0.109) val:-0.483 test:-0.484 [Accr] train:65.3% val:79.2% test:78.2% maxVal:89.3% maxTest:87.9%
# [09/50] [Loss] train:0.692 val:0.732 test:0.733 [Accr] train:61.0% val:60.1% test:60.4% maxVal:68.9% maxTest:68.2%
# [10/50] [Loss] train:0.683 val:0.671 test:0.680 [Accr] train:61.4% val:68.0% test:67.2% maxVal:68.9% maxTest:68.2%
# [43/50] [Loss] train:-0.530(f:-0.708+r:0.068+k:0.001+l:0.109) val:-0.755 test:-0.756 [Accr] train:74.8% val:99.2% test:99.1% maxVal:99.2% maxTest:99.1%
# [11/50] [Loss] train:0.683 val:0.876 test:0.883 [Accr] train:61.1% val:43.0% test:42.8% maxVal:68.9% maxTest:68.2%
# [44/50] [Loss] train:-0.410(f:-0.579+r:0.059+k:0.001+l:0.109) val:-0.458 test:-0.461 [Accr] train:65.9% val:74.3% test:74.5% maxVal:89.3% maxTest:87.9%
# [12/50] [Loss] train:0.668 val:0.667 test:0.668 [Accr] train:62.5% val:67.0% test:67.2% maxVal:68.9% maxTest:68.2%
# [13/50] [Loss] train:0.661 val:0.692 test:0.690 [Accr] train:63.3% val:62.9% test:63.5% maxVal:68.9% maxTest:68.2%
# [14/50] [Loss] train:0.650 val:0.701 test:0.707 [Accr] train:64.1% val:62.8% test:62.4% maxVal:68.9% maxTest:68.2%
# [44/50] [Loss] train:-0.530(f:-0.706+r:0.066+k:0.001+l:0.109) val:-0.754 test:-0.755 [Accr] train:74.8% val:99.2% test:99.2% maxVal:99.2% maxTest:99.1%
# [45/50] [Loss] train:-0.414(f:-0.583+r:0.059+k:0.001+l:0.109) val:-0.472 test:-0.470 [Accr] train:66.3% val:76.7% test:75.9% maxVal:89.3% maxTest:87.9%
# [15/50] [Loss] train:0.647 val:0.721 test:0.728 [Accr] train:64.1% val:59.7% test:58.2% maxVal:68.9% maxTest:68.2%
# [16/50] [Loss] train:0.641 val:0.741 test:0.752 [Accr] train:65.0% val:57.8% test:56.9% maxVal:68.9% maxTest:68.2%
# [17/50] [Loss] train:0.633 val:0.766 test:0.768 [Accr] train:65.5% val:54.8% test:54.2% maxVal:68.9% maxTest:68.2%
# [45/50] [Loss] train:-0.534(f:-0.709+r:0.065+k:0.001+l:0.109) val:-0.758 test:-0.759 [Accr] train:74.8% val:99.2% test:99.2% maxVal:99.2% maxTest:99.1%
# [18/50] [Loss] train:0.633 val:0.816 test:0.823 [Accr] train:65.4% val:49.5% test:49.0% maxVal:68.9% maxTest:68.2%
# [46/50] [Loss] train:-0.419(f:-0.586+r:0.058+k:0.001+l:0.109) val:-0.474 test:-0.476 [Accr] train:66.7% val:76.7% test:75.8% maxVal:89.3% maxTest:87.9%
# [19/50] [Loss] train:0.624 val:0.763 test:0.773 [Accr] train:66.4% val:54.8% test:54.3% maxVal:68.9% maxTest:68.2%
# [20/50] [Loss] train:0.617 val:0.688 test:0.696 [Accr] train:67.0% val:62.8% test:61.6% maxVal:68.9% maxTest:68.2%
# [21/50] [Loss] train:0.623 val:0.606 test:0.608 [Accr] train:66.1% val:72.0% test:71.4% maxVal:72.0% maxTest:71.4%
# [46/50] [Loss] train:-0.536(f:-0.709+r:0.063+k:0.001+l:0.109) val:-0.761 test:-0.761 [Accr] train:74.8% val:99.3% test:99.2% maxVal:99.3% maxTest:99.2%
# [47/50] [Loss] train:-0.424(f:-0.592+r:0.058+k:0.001+l:0.109) val:-0.457 test:-0.455 [Accr] train:67.3% val:73.7% test:73.1% maxVal:89.3% maxTest:87.9%
# [22/50] [Loss] train:0.608 val:0.696 test:0.695 [Accr] train:67.6% val:62.8% test:62.6% maxVal:72.0% maxTest:71.4%
# [23/50] [Loss] train:0.600 val:0.708 test:0.708 [Accr] train:68.6% val:60.3% test:60.4% maxVal:72.0% maxTest:71.4%
# [24/50] [Loss] train:0.596 val:0.707 test:0.701 [Accr] train:68.9% val:59.5% test:60.3% maxVal:72.0% maxTest:71.4%
# [47/50] [Loss] train:-0.541(f:-0.714+r:0.063+k:0.001+l:0.109) val:-0.768 test:-0.769 [Accr] train:74.8% val:99.2% test:99.3% maxVal:99.3% maxTest:99.2%
# [25/50] [Loss] train:0.597 val:0.827 test:0.827 [Accr] train:68.8% val:46.9% test:45.8% maxVal:72.0% maxTest:71.4%
# [48/50] [Loss] train:-0.426(f:-0.592+r:0.056+k:0.001+l:0.108) val:-0.464 test:-0.462 [Accr] train:67.7% val:75.2% test:75.0% maxVal:89.3% maxTest:87.9%
# [26/50] [Loss] train:0.585 val:0.676 test:0.682 [Accr] train:69.5% val:64.6% test:63.9% maxVal:72.0% maxTest:71.4%
# [27/50] [Loss] train:0.582 val:0.687 test:0.681 [Accr] train:70.2% val:62.9% test:63.1% maxVal:72.0% maxTest:71.4%
# [48/50] [Loss] train:-0.541(f:-0.711+r:0.061+k:0.001+l:0.108) val:-0.767 test:-0.768 [Accr] train:74.8% val:99.2% test:99.2% maxVal:99.3% maxTest:99.2%
# [28/50] [Loss] train:0.582 val:0.817 test:0.819 [Accr] train:69.9% val:47.0% test:46.7% maxVal:72.0% maxTest:71.4%
# [49/50] [Loss] train:-0.428(f:-0.593+r:0.055+k:0.001+l:0.108) val:-0.481 test:-0.478 [Accr] train:68.0% val:77.6% test:77.4% maxVal:89.3% maxTest:87.9%

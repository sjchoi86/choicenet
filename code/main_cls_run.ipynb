# %% [markdown]
# # Run Classification (MNIST) Tasks

# %%
import nbloader
from main_cls_config import worker_class
if __name__ == "__main__": 
    print ("Packages loaded.")
# Out:
# Packages loaded.

# %% [markdown]
# ### Instantiate Workers

# %%
nWorker = 18
maxGPU  = 8
WORKERS = ['']*nWorker
for i in range(nWorker):
    WORKERS[i] = worker_class(_idx=i,_maxProcessID=nWorker,_maxGPU=maxGPU,_name='Worker_%02d'%(i)
                              ,_period=1.0,_maxTick=10,_VERBOSE=True)
# Out:
# [Worker_00] Instantiated.
# [Worker_01] Instantiated.
# [Worker_02] Instantiated.
# [Worker_03] Instantiated.
# [Worker_04] Instantiated.
# [Worker_05] Instantiated.
# [Worker_06] Instantiated.
# [Worker_07] Instantiated.
# [Worker_08] Instantiated.
# [Worker_09] Instantiated.
# [Worker_10] Instantiated.
# [Worker_11] Instantiated.
# [Worker_12] Instantiated.
# [Worker_13] Instantiated.
# [Worker_14] Instantiated.
# [Worker_15] Instantiated.
# [Worker_16] Instantiated.
# [Worker_17] Instantiated.

# %% [markdown]
# ### Start Workers

# %%
for i in range(nWorker):
    WORKERS[i].start(); # Start process
# Out:
# Starting [Worker_00]
# Starting [Worker_01]
# Starting [Worker_02]
# Starting [Worker_03]
# Starting [Worker_04]
# Starting [Worker_05]
# Starting [Worker_06]
# Starting [Worker_07]
# Starting [Worker_08]
# Starting [Worker_09]
# Starting [Worker_10]
# Starting [Worker_11]
# Starting [Worker_12]
# Starting [Worker_13]
# Starting [Worker_14]
# Starting [Worker_15]
# Starting [Worker_16]
# Starting [Worker_17]
# processID:[0/18] GPU_ID:[0] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[1/18] GPU_ID:[1] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[2/18] GPU_ID:[2] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[3/18] GPU_ID:[3] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[4/18] GPU_ID:[4] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[5/18] GPU_ID:[5] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[6/18] GPU_ID:[6] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[7/18] GPU_ID:[7] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[8/18] GPU_ID:[0] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[9/18] GPU_ID:[1] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[10/18] GPU_ID:[2] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[11/18] GPU_ID:[3] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[12/18] GPU_ID:[4] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[13/18] GPU_ID:[5] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[14/18] GPU_ID:[6] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[15/18] GPU_ID:[7] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[16/18] GPU_ID:[0] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# processID:[17/18] GPU_ID:[1] #Config:[1]
# Extracting ../data/train-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/train-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-images-idx3-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Extracting ../data/t10k-labels-idx1-ubyte.gz
# Text name: ../res/res_mnist_rs_err90_basic_cnn.txt
# Text name: ../res/res_mnist_b_err95_basic_cnn.txt
# Text name: ../res/res_mnist_b_err90_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err50_basic_cnn.txt
# Text name: ../res/res_mnist_rs_err50_basic_cnn.txt
# Text name: ../res/res_mnist_b_err50_basic_cnn.txt
# Text name: ../res/res_mnist_rs_err95_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err95_basic_cnn.txt
# Text name: ../res/res_mnist_rp_err90_basic_cnn.txt
# Text name: ../res/res_mnist_b_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_b_err95_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err90_basic_choiceNet.txt
# Text name: ../res/res_mnist_b_err50_basic_choiceNet.txt
# Text name: ../res/res_mnist_rp_err50_basic_choiceNet.txt
# Text name: ../res/res_mnist_rs_err50_basic_choiceNet.txt
# [00/40] [Loss] train:2.339 val:1.970 test:1.956 [Accr] train:13.6% val:41.5% test:42.2% maxVal:41.5% maxTest:42.2%
# [00/40] [Loss] train:0.953 val:0.995 test:0.995 [Accr] train:54.6% val:55.7% test:56.0% maxVal:55.7% maxTest:56.0%
# [00/40] [Loss] train:1.219 val:1.081 test:1.101 [Accr] train:46.2% val:58.5% test:57.6% maxVal:58.5% maxTest:57.6%
# [00/40] [Loss] train:1.871 val:0.982 test:0.987 [Accr] train:48.1% val:87.0% test:86.9% maxVal:87.0% maxTest:86.9%
# [00/40] [Loss] train:0.862 val:0.622 test:0.622 [Accr] train:67.0% val:81.4% test:81.0% maxVal:81.4% maxTest:81.0%
# [00/40] [Loss] train:1.215 val:1.150 test:1.157 [Accr] train:45.3% val:50.3% test:51.0% maxVal:50.3% maxTest:51.0%
# [00/40] [Loss] train:2.354 val:2.144 test:2.133 [Accr] train:11.4% val:26.6% test:28.1% maxVal:26.6% maxTest:28.1%
# [00/40] [Loss] train:0.951 val:1.058 test:1.056 [Accr] train:54.5% val:51.2% test:51.3% maxVal:51.2% maxTest:51.3%
# [00/40] [Loss] train:1.048 val:0.648 test:0.651 [Accr] train:65.5% val:86.0% test:86.0% maxVal:86.0% maxTest:86.0%
# [01/40] [Loss] train:2.300 val:1.922 test:1.912 [Accr] train:15.0% val:54.2% test:55.0% maxVal:54.2% maxTest:55.0%
# [01/40] [Loss] train:0.846 val:0.875 test:0.889 [Accr] train:56.0% val:59.2% test:58.0% maxVal:59.2% maxTest:58.0%
# [00/40] [Loss] train:0.059(f:-0.105+r:0.047+k:0.001+l:0.116) val:0.011 test:0.001 [Accr] train:12.0% val:36.3% test:38.7% maxVal:36.3% maxTest:38.7%
# [01/40] [Loss] train:1.039 val:0.954 test:0.963 [Accr] train:49.0% val:55.7% test:55.6% maxVal:58.5% maxTest:57.6%
# [01/40] [Loss] train:1.045 val:0.968 test:0.973 [Accr] train:48.4% val:55.0% test:55.6% maxVal:55.0% maxTest:55.6%
# [00/40] [Loss] train:0.051(f:-0.115+r:0.049+k:0.001+l:0.116) val:-0.060 test:-0.071 [Accr] train:15.3% val:59.3% test:61.4% maxVal:59.3% maxTest:61.4%
# [01/40] [Loss] train:1.814 val:0.896 test:0.897 [Accr] train:50.6% val:91.6% test:91.9% maxVal:91.6% maxTest:91.9%
# [00/40] [Loss] train:-0.237(f:-0.418+r:0.064+k:0.001+l:0.116) val:-0.338 test:-0.342 [Accr] train:68.3% val:88.1% test:87.7% maxVal:88.1% maxTest:87.7%
# [01/40] [Loss] train:0.745 val:0.520 test:0.530 [Accr] train:69.1% val:84.7% test:83.2% maxVal:84.7% maxTest:83.2%
# [00/40] [Loss] train:-0.148(f:-0.327+r:0.062+k:0.001+l:0.116) val:-0.265 test:-0.268 [Accr] train:53.1% val:79.5% test:78.7% maxVal:79.5% maxTest:78.7%
# [00/40] [Loss] train:-0.103(f:-0.278+r:0.058+k:0.001+l:0.116) val:-0.212 test:-0.222 [Accr] train:44.0% val:70.8% test:72.5% maxVal:70.8% maxTest:72.5%
# [00/40] [Loss] train:-0.113(f:-0.289+r:0.059+k:0.001+l:0.116) val:-0.248 test:-0.255 [Accr] train:46.0% val:76.7% test:77.4% maxVal:76.7% maxTest:77.4%
# [02/40] [Loss] train:2.286 val:1.908 test:1.900 [Accr] train:16.0% val:61.5% test:62.4% maxVal:61.5% maxTest:62.4%
# [02/40] [Loss] train:0.799 val:0.833 test:0.844 [Accr] train:56.9% val:59.9% test:58.4% maxVal:59.9% maxTest:58.4%
# [01/40] [Loss] train:2.320 val:2.094 test:2.090 [Accr] train:12.2% val:33.6% test:34.1% maxVal:33.6% maxTest:34.1%
# [00/40] [Loss] train:-0.110(f:-0.288+r:0.061+k:0.001+l:0.116) val:-0.302 test:-0.308 [Accr] train:47.8% val:86.2% test:86.6% maxVal:86.2% maxTest:86.6%
# [00/40] [Loss] train:-0.218(f:-0.398+r:0.064+k:0.001+l:0.116) val:-0.334 test:-0.341 [Accr] train:65.5% val:87.6% test:87.6% maxVal:87.6% maxTest:87.6%
# [00/40] [Loss] train:-0.140(f:-0.318+r:0.061+k:0.001+l:0.116) val:-0.246 test:-0.249 [Accr] train:51.7% val:76.8% test:76.0% maxVal:76.8% maxTest:76.0%
# [02/40] [Loss] train:0.959 val:0.868 test:0.876 [Accr] train:50.9% val:60.3% test:60.3% maxVal:60.3% maxTest:60.3%
# [02/40] [Loss] train:0.964 val:0.941 test:0.956 [Accr] train:50.1% val:52.0% test:51.6% maxVal:55.0% maxTest:55.6%
# [02/40] [Loss] train:1.786 val:0.838 test:0.848 [Accr] train:51.7% val:93.7% test:93.5% maxVal:93.7% maxTest:93.5%
# [02/40] [Loss] train:0.691 val:0.432 test:0.446 [Accr] train:71.7% val:89.0% test:87.4% maxVal:89.0% maxTest:87.4%
# [01/40] [Loss] train:0.847 val:0.955 test:0.967 [Accr] train:55.8% val:52.0% test:51.2% maxVal:52.0% maxTest:51.2%
# [01/40] [Loss] train:0.887 val:0.525 test:0.530 [Accr] train:68.5% val:90.3% test:89.9% maxVal:90.3% maxTest:89.9%
# [01/40] [Loss] train:0.056(f:-0.107+r:0.047+k:0.001+l:0.115) val:-0.042 test:-0.049 [Accr] train:12.9% val:54.2% test:56.4% maxVal:54.2% maxTest:56.4%
# [01/40] [Loss] train:0.043(f:-0.123+r:0.050+k:0.001+l:0.115) val:-0.151 test:-0.155 [Accr] train:17.0% val:77.3% test:78.4% maxVal:77.3% maxTest:78.4%
# [01/40] [Loss] train:-0.144(f:-0.324+r:0.063+k:0.001+l:0.115) val:-0.299 test:-0.301 [Accr] train:46.6% val:76.1% test:77.4% maxVal:76.1% maxTest:77.4%
# [01/40] [Loss] train:-0.196(f:-0.379+r:0.067+k:0.001+l:0.115) val:-0.362 test:-0.360 [Accr] train:55.2% val:85.6% test:84.8% maxVal:85.6% maxTest:84.8%
# [01/40] [Loss] train:-0.309(f:-0.496+r:0.070+k:0.001+l:0.115) val:-0.441 test:-0.441 [Accr] train:71.8% val:92.7% test:92.7% maxVal:92.7% maxTest:92.7%
# [01/40] [Loss] train:-0.159(f:-0.340+r:0.065+k:0.001+l:0.115) val:-0.344 test:-0.346 [Accr] train:49.4% val:85.7% test:86.2% maxVal:85.7% maxTest:86.2%
# [03/40] [Loss] train:0.775 val:0.829 test:0.842 [Accr] train:57.3% val:57.9% test:56.5% maxVal:59.9% maxTest:58.4%
# [03/40] [Loss] train:2.277 val:1.894 test:1.889 [Accr] train:16.6% val:67.2% test:67.4% maxVal:67.2% maxTest:67.4%
# [03/40] [Loss] train:0.913 val:0.839 test:0.842 [Accr] train:52.0% val:59.2% test:59.1% maxVal:60.3% maxTest:60.3%
# [03/40] [Loss] train:0.917 val:0.881 test:0.888 [Accr] train:51.3% val:54.8% test:54.6% maxVal:55.0% maxTest:55.6%
# [03/40] [Loss] train:1.771 val:0.851 test:0.856 [Accr] train:52.1% val:94.4% test:94.3% maxVal:94.4% maxTest:94.3%
# [03/40] [Loss] train:0.663 val:0.429 test:0.441 [Accr] train:71.9% val:88.6% test:87.6% maxVal:89.0% maxTest:87.4%
# [02/40] [Loss] train:2.304 val:2.093 test:2.094 [Accr] train:12.7% val:37.5% test:38.3% maxVal:37.5% maxTest:38.3%
# [02/40] [Loss] train:0.801 val:0.905 test:0.913 [Accr] train:56.6% val:52.6% test:51.8% maxVal:52.6% maxTest:51.8%
# [02/40] [Loss] train:0.816 val:0.499 test:0.500 [Accr] train:69.3% val:90.1% test:89.6% maxVal:90.3% maxTest:89.9%
# [04/40] [Loss] train:0.750 val:0.792 test:0.810 [Accr] train:58.2% val:59.9% test:58.1% maxVal:59.9% maxTest:58.1%
# [04/40] [Loss] train:2.272 val:1.921 test:1.920 [Accr] train:16.9% val:68.6% test:68.4% maxVal:68.6% maxTest:68.4%
# [04/40] [Loss] train:0.880 val:0.799 test:0.807 [Accr] train:53.1% val:64.0% test:63.5% maxVal:64.0% maxTest:63.5%
# [04/40] [Loss] train:0.882 val:0.842 test:0.855 [Accr] train:52.4% val:57.3% test:56.3% maxVal:57.3% maxTest:56.3%
# [04/40] [Loss] train:1.756 val:0.790 test:0.799 [Accr] train:52.5% val:95.0% test:94.9% maxVal:95.0% maxTest:94.9%
# [04/40] [Loss] train:0.641 val:0.458 test:0.474 [Accr] train:71.7% val:87.0% test:85.5% maxVal:89.0% maxTest:87.4%
# [02/40] [Loss] train:0.053(f:-0.110+r:0.046+k:0.001+l:0.115) val:-0.073 test:-0.083 [Accr] train:13.6% val:66.8% test:69.3% maxVal:66.8% maxTest:69.3%
# [02/40] [Loss] train:0.037(f:-0.130+r:0.051+k:0.001+l:0.115) val:-0.210 test:-0.216 [Accr] train:17.6% val:83.7% test:84.3% maxVal:83.7% maxTest:84.3%
# [02/40] [Loss] train:-0.166(f:-0.349+r:0.066+k:0.001+l:0.115) val:-0.341 test:-0.342 [Accr] train:48.3% val:79.3% test:80.1% maxVal:79.3% maxTest:80.1%
# [02/40] [Loss] train:-0.220(f:-0.406+r:0.070+k:0.001+l:0.115) val:-0.407 test:-0.405 [Accr] train:56.1% val:87.8% test:87.0% maxVal:87.8% maxTest:87.0%
# [02/40] [Loss] train:-0.343(f:-0.534+r:0.074+k:0.001+l:0.115) val:-0.488 test:-0.487 [Accr] train:73.6% val:94.9% test:95.0% maxVal:94.9% maxTest:95.0%
# [01/40] [Loss] train:-0.156(f:-0.340+r:0.067+k:0.001+l:0.115) val:-0.406 test:-0.407 [Accr] train:50.5% val:91.9% test:92.0% maxVal:91.9% maxTest:92.0%
# [01/40] [Loss] train:-0.288(f:-0.474+r:0.070+k:0.001+l:0.115) val:-0.438 test:-0.440 [Accr] train:69.2% val:92.6% test:92.8% maxVal:92.6% maxTest:92.8%
# [01/40] [Loss] train:-0.183(f:-0.365+r:0.066+k:0.001+l:0.115) val:-0.335 test:-0.333 [Accr] train:53.5% val:82.3% test:81.3% maxVal:82.3% maxTest:81.3%
# [02/40] [Loss] train:-0.183(f:-0.368+r:0.068+k:0.001+l:0.115) val:-0.397 test:-0.400 [Accr] train:51.1% val:90.2% test:90.3% maxVal:90.2% maxTest:90.3%
# [05/40] [Loss] train:0.732 val:0.707 test:0.717 [Accr] train:59.4% val:67.3% test:66.4% maxVal:67.3% maxTest:66.4%
# [05/40] [Loss] train:2.265 val:1.870 test:1.869 [Accr] train:17.5% val:73.2% test:73.0% maxVal:73.2% maxTest:73.0%
# [05/40] [Loss] train:0.852 val:0.780 test:0.789 [Accr] train:54.1% val:62.7% test:61.5% maxVal:64.0% maxTest:63.5%
# [05/40] [Loss] train:0.859 val:0.882 test:0.894 [Accr] train:52.8% val:48.7% test:47.9% maxVal:57.3% maxTest:56.3%
# [03/40] [Loss] train:2.295 val:2.116 test:2.114 [Accr] train:13.2% val:37.9% test:38.7% maxVal:37.9% maxTest:38.7%
# [05/40] [Loss] train:1.745 val:0.786 test:0.798 [Accr] train:52.8% val:95.8% test:95.5% maxVal:95.8% maxTest:95.5%
# [05/40] [Loss] train:0.621 val:0.408 test:0.420 [Accr] train:73.3% val:90.3% test:89.4% maxVal:90.3% maxTest:89.4%
# [03/40] [Loss] train:0.777 val:0.910 test:0.918 [Accr] train:57.0% val:49.8% test:49.4% maxVal:52.6% maxTest:51.8%
# [03/40] [Loss] train:0.765 val:0.459 test:0.462 [Accr] train:70.8% val:91.8% test:91.5% maxVal:91.8% maxTest:91.5%
# [03/40] [Loss] train:0.050(f:-0.111+r:0.045+k:0.001+l:0.115) val:-0.098 test:-0.111 [Accr] train:13.8% val:72.7% test:74.0% maxVal:72.7% maxTest:74.0%
# [03/40] [Loss] train:0.034(f:-0.133+r:0.051+k:0.001+l:0.115) val:-0.238 test:-0.247 [Accr] train:17.8% val:86.1% test:86.6% maxVal:86.1% maxTest:86.6%
# [03/40] [Loss] train:-0.182(f:-0.367+r:0.068+k:0.001+l:0.115) val:-0.369 test:-0.377 [Accr] train:49.3% val:82.5% test:83.1% maxVal:82.5% maxTest:83.1%
# [03/40] [Loss] train:-0.237(f:-0.425+r:0.072+k:0.001+l:0.115) val:-0.443 test:-0.444 [Accr] train:56.6% val:89.4% test:88.5% maxVal:89.4% maxTest:88.5%
# [06/40] [Loss] train:0.724 val:0.759 test:0.779 [Accr] train:59.4% val:61.8% test:59.9% maxVal:67.3% maxTest:66.4%
# [03/40] [Loss] train:-0.369(f:-0.562+r:0.077+k:0.001+l:0.115) val:-0.522 test:-0.521 [Accr] train:74.4% val:95.9% test:96.0% maxVal:95.9% maxTest:96.0%
# [06/40] [Loss] train:2.260 val:1.845 test:1.843 [Accr] train:17.9% val:75.8% test:75.6% maxVal:75.8% maxTest:75.6%
# [06/40] [Loss] train:0.832 val:0.771 test:0.777 [Accr] train:54.6% val:62.0% test:61.3% maxVal:64.0% maxTest:63.5%
# [06/40] [Loss] train:0.838 val:0.795 test:0.804 [Accr] train:54.1% val:60.4% test:60.1% maxVal:60.4% maxTest:60.1%
# [03/40] [Loss] train:-0.201(f:-0.387+r:0.070+k:0.001+l:0.115) val:-0.427 test:-0.435 [Accr] train:51.9% val:92.4% test:92.4% maxVal:92.4% maxTest:92.4%
# [06/40] [Loss] train:1.731 val:0.771 test:0.784 [Accr] train:53.0% val:95.9% test:96.0% maxVal:95.9% maxTest:96.0%
# [06/40] [Loss] train:0.608 val:0.386 test:0.399 [Accr] train:73.9% val:90.5% test:89.1% maxVal:90.5% maxTest:89.1%
# [04/40] [Loss] train:2.291 val:2.100 test:2.098 [Accr] train:13.6% val:44.5% test:44.8% maxVal:44.5% maxTest:44.8%
# [04/40] [Loss] train:0.751 val:0.832 test:0.849 [Accr] train:57.8% val:55.4% test:54.3% maxVal:55.4% maxTest:54.3%
# [02/40] [Loss] train:-0.181(f:-0.367+r:0.070+k:0.001+l:0.115) val:-0.458 test:-0.458 [Accr] train:51.6% val:94.0% test:94.0% maxVal:94.0% maxTest:94.0%
# [02/40] [Loss] train:-0.323(f:-0.512+r:0.073+k:0.001+l:0.115) val:-0.487 test:-0.488 [Accr] train:70.9% val:94.9% test:94.8% maxVal:94.9% maxTest:94.8%
# [02/40] [Loss] train:-0.207(f:-0.392+r:0.069+k:0.001+l:0.115) val:-0.379 test:-0.376 [Accr] train:54.4% val:84.5% test:83.6% maxVal:84.5% maxTest:83.6%
# [07/40] [Loss] train:0.707 val:0.705 test:0.719 [Accr] train:60.4% val:65.9% test:63.4% maxVal:67.3% maxTest:66.4%
# [04/40] [Loss] train:0.739 val:0.436 test:0.438 [Accr] train:71.2% val:92.6% test:92.4% maxVal:92.6% maxTest:92.4%
# [07/40] [Loss] train:2.257 val:1.859 test:1.861 [Accr] train:17.9% val:73.7% test:71.9% maxVal:75.8% maxTest:75.6%
# [07/40] [Loss] train:0.814 val:0.782 test:0.781 [Accr] train:55.8% val:59.1% test:59.1% maxVal:64.0% maxTest:63.5%
# [07/40] [Loss] train:0.818 val:0.807 test:0.815 [Accr] train:54.9% val:57.7% test:57.1% maxVal:60.4% maxTest:60.1%
# [07/40] [Loss] train:1.722 val:0.758 test:0.774 [Accr] train:53.1% val:96.1% test:96.0% maxVal:96.1% maxTest:96.0%
# [07/40] [Loss] train:0.592 val:0.384 test:0.396 [Accr] train:74.5% val:91.3% test:90.5% maxVal:91.3% maxTest:90.5%
# [04/40] [Loss] train:0.048(f:-0.113+r:0.045+k:0.001+l:0.115) val:-0.109 test:-0.122 [Accr] train:14.1% val:75.2% test:76.6% maxVal:75.2% maxTest:76.6%
# [04/40] [Loss] train:0.032(f:-0.135+r:0.051+k:0.001+l:0.115) val:-0.256 test:-0.266 [Accr] train:18.1% val:88.3% test:88.5% maxVal:88.3% maxTest:88.5%
# [04/40] [Loss] train:-0.196(f:-0.381+r:0.070+k:0.001+l:0.115) val:-0.393 test:-0.398 [Accr] train:49.9% val:84.6% test:84.7% maxVal:84.6% maxTest:84.7%
# [04/40] [Loss] train:-0.250(f:-0.439+r:0.073+k:0.001+l:0.115) val:-0.469 test:-0.468 [Accr] train:57.0% val:90.3% test:89.4% maxVal:90.3% maxTest:89.4%
# [04/40] [Loss] train:-0.384(f:-0.578+r:0.077+k:0.001+l:0.115) val:-0.544 test:-0.543 [Accr] train:74.9% val:96.6% test:96.5% maxVal:96.6% maxTest:96.5%
# [04/40] [Loss] train:-0.214(f:-0.402+r:0.072+k:0.001+l:0.115) val:-0.457 test:-0.460 [Accr] train:52.6% val:94.1% test:93.9% maxVal:94.1% maxTest:93.9%
# [08/40] [Loss] train:0.704 val:0.621 test:0.626 [Accr] train:61.1% val:73.9% test:73.8% maxVal:73.9% maxTest:73.8%
# [08/40] [Loss] train:2.250 val:1.840 test:1.844 [Accr] train:18.3% val:76.7% test:76.2% maxVal:76.7% maxTest:76.2%
# [08/40] [Loss] train:0.801 val:0.729 test:0.729 [Accr] train:56.3% val:65.5% test:64.4% maxVal:65.5% maxTest:64.4%
# [08/40] [Loss] train:0.802 val:0.810 test:0.816 [Accr] train:55.8% val:56.0% test:55.1% maxVal:60.4% maxTest:60.1%
# [05/40] [Loss] train:2.286 val:2.105 test:2.102 [Accr] train:14.1% val:45.9% test:44.9% maxVal:45.9% maxTest:44.9%
# [08/40] [Loss] train:1.714 val:0.750 test:0.762 [Accr] train:53.3% val:96.3% test:96.4% maxVal:96.3% maxTest:96.4%
# [08/40] [Loss] train:0.599 val:0.301 test:0.305 [Accr] train:75.6% val:94.8% test:94.6% maxVal:94.8% maxTest:94.6%
# [05/40] [Loss] train:0.734 val:0.763 test:0.773 [Accr] train:58.9% val:61.4% test:60.6% maxVal:61.4% maxTest:60.6%
# [05/40] [Loss] train:0.712 val:0.432 test:0.433 [Accr] train:71.8% val:92.8% test:92.5% maxVal:92.8% maxTest:92.5%
# [09/40] [Loss] train:0.687 val:0.698 test:0.699 [Accr] train:61.7% val:64.5% test:65.0% maxVal:73.9% maxTest:73.8%
# [05/40] [Loss] train:0.046(f:-0.114+r:0.044+k:0.001+l:0.115) val:-0.127 test:-0.138 [Accr] train:14.2% val:77.6% test:78.5% maxVal:77.6% maxTest:78.5%
# [05/40] [Loss] train:0.029(f:-0.137+r:0.051+k:0.001+l:0.115) val:-0.281 test:-0.285 [Accr] train:18.2% val:90.0% test:89.8% maxVal:90.0% maxTest:89.8%
# [09/40] [Loss] train:2.247 val:1.859 test:1.862 [Accr] train:18.5% val:74.8% test:74.0% maxVal:76.7% maxTest:76.2%
# [09/40] [Loss] train:0.788 val:0.752 test:0.749 [Accr] train:56.9% val:61.0% test:61.1% maxVal:65.5% maxTest:64.4%
# [09/40] [Loss] train:0.790 val:0.796 test:0.803 [Accr] train:56.5% val:55.1% test:55.0% maxVal:60.4% maxTest:60.1%
# [05/40] [Loss] train:-0.205(f:-0.392+r:0.070+k:0.001+l:0.115) val:-0.414 test:-0.417 [Accr] train:50.4% val:86.2% test:86.0% maxVal:86.2% maxTest:86.0%
# [05/40] [Loss] train:-0.263(f:-0.453+r:0.074+k:0.001+l:0.115) val:-0.489 test:-0.486 [Accr] train:57.2% val:90.9% test:89.5% maxVal:90.9% maxTest:89.5%
# [05/40] [Loss] train:-0.399(f:-0.594+r:0.079+k:0.001+l:0.115) val:-0.563 test:-0.561 [Accr] train:75.3% val:97.1% test:97.0% maxVal:97.1% maxTest:97.0%
# [03/40] [Loss] train:-0.199(f:-0.388+r:0.073+k:0.001+l:0.115) val:-0.493 test:-0.493 [Accr] train:52.4% val:95.1% test:95.3% maxVal:95.1% maxTest:95.3%
# [03/40] [Loss] train:-0.347(f:-0.540+r:0.076+k:0.001+l:0.115) val:-0.519 test:-0.520 [Accr] train:71.8% val:95.7% test:95.9% maxVal:95.7% maxTest:95.9%
# [09/40] [Loss] train:1.708 val:0.771 test:0.782 [Accr] train:53.4% val:96.4% test:96.3% maxVal:96.4% maxTest:96.3%
# [09/40] [Loss] train:0.574 val:0.394 test:0.402 [Accr] train:74.6% val:90.3% test:89.4% maxVal:94.8% maxTest:94.6%
# [03/40] [Loss] train:-0.222(f:-0.409+r:0.071+k:0.001+l:0.115) val:-0.412 test:-0.413 [Accr] train:54.8% val:86.5% test:85.5% maxVal:86.5% maxTest:85.5%
# [05/40] [Loss] train:-0.223(f:-0.412+r:0.073+k:0.001+l:0.115) val:-0.479 test:-0.482 [Accr] train:53.0% val:94.9% test:95.0% maxVal:94.9% maxTest:95.0%
# [06/40] [Loss] train:2.281 val:2.110 test:2.106 [Accr] train:14.3% val:45.7% test:47.1% maxVal:45.9% maxTest:44.9%
# [06/40] [Loss] train:0.726 val:0.807 test:0.826 [Accr] train:59.2% val:56.8% test:55.1% maxVal:61.4% maxTest:60.6%
# [10/40] [Loss] train:0.681 val:0.627 test:0.635 [Accr] train:62.1% val:72.4% test:71.6% maxVal:73.9% maxTest:73.8%
# [10/40] [Loss] train:2.242 val:1.842 test:1.847 [Accr] train:18.8% val:76.3% test:75.3% maxVal:76.7% maxTest:76.2%
# [10/40] [Loss] train:0.776 val:0.728 test:0.726 [Accr] train:57.5% val:64.7% test:65.7% maxVal:65.5% maxTest:64.4%
# [10/40] [Loss] train:0.781 val:0.780 test:0.789 [Accr] train:57.3% val:57.8% test:57.6% maxVal:60.4% maxTest:60.1%
# [06/40] [Loss] train:0.697 val:0.406 test:0.408 [Accr] train:72.3% val:93.3% test:93.1% maxVal:93.3% maxTest:93.1%
# [10/40] [Loss] train:1.698 val:0.743 test:0.756 [Accr] train:53.5% val:96.5% test:96.7% maxVal:96.5% maxTest:96.7%
# [10/40] [Loss] train:0.568 val:0.320 test:0.328 [Accr] train:75.8% val:94.0% test:93.2% maxVal:94.8% maxTest:94.6%
# [06/40] [Loss] train:0.044(f:-0.114+r:0.042+k:0.001+l:0.115) val:-0.131 test:-0.141 [Accr] train:14.4% val:79.1% test:80.0% maxVal:79.1% maxTest:80.0%
# [06/40] [Loss] train:0.027(f:-0.139+r:0.050+k:0.001+l:0.115) val:-0.290 test:-0.297 [Accr] train:18.3% val:91.0% test:91.3% maxVal:91.0% maxTest:91.3%
# [06/40] [Loss] train:-0.213(f:-0.401+r:0.072+k:0.001+l:0.115) val:-0.429 test:-0.434 [Accr] train:50.8% val:88.5% test:88.1% maxVal:88.5% maxTest:88.1%
# [06/40] [Loss] train:-0.271(f:-0.461+r:0.075+k:0.001+l:0.115) val:-0.504 test:-0.502 [Accr] train:57.5% val:91.7% test:90.5% maxVal:91.7% maxTest:90.5%
# [06/40] [Loss] train:-0.410(f:-0.605+r:0.079+k:0.001+l:0.115) val:-0.577 test:-0.575 [Accr] train:75.5% val:97.4% test:97.3% maxVal:97.4% maxTest:97.3%
# [11/40] [Loss] train:0.679 val:0.815 test:0.824 [Accr] train:61.6% val:50.7% test:50.0% maxVal:73.9% maxTest:73.8%
# [11/40] [Loss] train:2.236 val:1.835 test:1.838 [Accr] train:19.1% val:75.8% test:75.5% maxVal:76.7% maxTest:76.2%
# [11/40] [Loss] train:0.763 val:0.735 test:0.733 [Accr] train:58.6% val:62.9% test:63.9% maxVal:65.5% maxTest:64.4%
# [11/40] [Loss] train:0.768 val:0.802 test:0.804 [Accr] train:58.0% val:54.4% test:54.5% maxVal:60.4% maxTest:60.1%
# [06/40] [Loss] train:-0.232(f:-0.421+r:0.073+k:0.001+l:0.115) val:-0.493 test:-0.497 [Accr] train:53.2% val:95.9% test:95.7% maxVal:95.9% maxTest:95.7%
# [07/40] [Loss] train:2.278 val:2.082 test:2.075 [Accr] train:14.7% val:49.1% test:50.4% maxVal:49.1% maxTest:50.4%
# [11/40] [Loss] train:0.564 val:0.413 test:0.418 [Accr] train:74.5% val:89.1% test:87.9% maxVal:94.8% maxTest:94.6%
# [11/40] [Loss] train:1.692 val:0.741 test:0.756 [Accr] train:53.6% val:96.8% test:96.7% maxVal:96.8% maxTest:96.7%
# [07/40] [Loss] train:0.712 val:0.799 test:0.812 [Accr] train:59.7% val:55.0% test:53.5% maxVal:61.4% maxTest:60.6%
# [04/40] [Loss] train:-0.212(f:-0.402+r:0.074+k:0.001+l:0.115) val:-0.521 test:-0.519 [Accr] train:52.9% val:96.1% test:96.1% maxVal:96.1% maxTest:96.1%
# [07/40] [Loss] train:0.679 val:0.395 test:0.396 [Accr] train:72.5% val:93.6% test:93.4% maxVal:93.6% maxTest:93.4%
# [04/40] [Loss] train:-0.366(f:-0.559+r:0.078+k:0.001+l:0.115) val:-0.546 test:-0.546 [Accr] train:72.4% val:96.6% test:96.5% maxVal:96.6% maxTest:96.5%
# [04/40] [Loss] train:-0.235(f:-0.423+r:0.071+k:0.001+l:0.115) val:-0.437 test:-0.437 [Accr] train:55.1% val:87.2% test:85.9% maxVal:87.2% maxTest:85.9%
# [12/40] [Loss] train:0.667 val:0.609 test:0.612 [Accr] train:63.0% val:74.0% test:73.7% maxVal:74.0% maxTest:73.7%
# [12/40] [Loss] train:2.232 val:1.817 test:1.825 [Accr] train:19.2% val:76.1% test:75.2% maxVal:76.7% maxTest:76.2%
# [12/40] [Loss] train:0.762 val:0.752 test:0.749 [Accr] train:58.3% val:59.9% test:59.6% maxVal:65.5% maxTest:64.4%
# [12/40] [Loss] train:0.759 val:0.770 test:0.770 [Accr] train:58.4% val:57.7% test:57.9% maxVal:60.4% maxTest:60.1%
# [07/40] [Loss] train:0.041(f:-0.115+r:0.041+k:0.001+l:0.115) val:-0.141 test:-0.151 [Accr] train:14.4% val:80.4% test:81.1% maxVal:80.4% maxTest:81.1%
# [07/40] [Loss] train:0.025(f:-0.141+r:0.049+k:0.001+l:0.115) val:-0.302 test:-0.309 [Accr] train:18.5% val:91.8% test:91.8% maxVal:91.8% maxTest:91.8%
# [07/40] [Loss] train:-0.220(f:-0.408+r:0.072+k:0.001+l:0.115) val:-0.443 test:-0.449 [Accr] train:51.0% val:88.9% test:88.1% maxVal:88.9% maxTest:88.1%
# [07/40] [Loss] train:-0.278(f:-0.469+r:0.075+k:0.001+l:0.115) val:-0.517 test:-0.516 [Accr] train:57.7% val:92.0% test:90.9% maxVal:92.0% maxTest:90.9%
# [07/40] [Loss] train:-0.420(f:-0.616+r:0.080+k:0.001+l:0.115) val:-0.590 test:-0.589 [Accr] train:75.7% val:97.8% test:97.5% maxVal:97.8% maxTest:97.5%
# [12/40] [Loss] train:0.556 val:0.304 test:0.312 [Accr] train:76.2% val:94.3% test:94.0% maxVal:94.8% maxTest:94.6%
# [12/40] [Loss] train:1.687 val:0.753 test:0.763 [Accr] train:53.7% val:96.9% test:96.7% maxVal:96.9% maxTest:96.7%
# [07/40] [Loss] train:-0.238(f:-0.429+r:0.075+k:0.001+l:0.115) val:-0.506 test:-0.511 [Accr] train:53.5% val:96.3% test:96.2% maxVal:96.3% maxTest:96.2%
# [13/40] [Loss] train:0.658 val:0.657 test:0.657 [Accr] train:63.6% val:66.8% test:67.2% maxVal:74.0% maxTest:73.7%
# [08/40] [Loss] train:2.274 val:2.076 test:2.074 [Accr] train:15.0% val:51.2% test:51.8% maxVal:51.2% maxTest:51.8%
# [13/40] [Loss] train:2.227 val:1.798 test:1.804 [Accr] train:19.3% val:76.3% test:75.2% maxVal:76.7% maxTest:76.2%
# [08/40] [Loss] train:0.705 val:0.676 test:0.681 [Accr] train:60.3% val:68.1% test:67.7% maxVal:68.1% maxTest:67.7%
# [13/40] [Loss] train:0.746 val:0.720 test:0.714 [Accr] train:59.9% val:63.3% test:64.7% maxVal:65.5% maxTest:64.4%
# [13/40] [Loss] train:0.755 val:0.771 test:0.771 [Accr] train:58.6% val:59.0% test:58.8% maxVal:60.4% maxTest:60.1%
# [08/40] [Loss] train:0.664 val:0.397 test:0.396 [Accr] train:72.8% val:94.0% test:93.8% maxVal:94.0% maxTest:93.8%
# [13/40] [Loss] train:0.545 val:0.325 test:0.331 [Accr] train:76.2% val:93.9% test:93.2% maxVal:94.8% maxTest:94.6%
# [13/40] [Loss] train:1.679 val:0.704 test:0.722 [Accr] train:53.7% val:97.2% test:96.7% maxVal:97.2% maxTest:96.7%
# [08/40] [Loss] train:0.039(f:-0.116+r:0.039+k:0.001+l:0.114) val:-0.141 test:-0.152 [Accr] train:14.5% val:82.5% test:82.7% maxVal:82.5% maxTest:82.7%
# [08/40] [Loss] train:0.023(f:-0.142+r:0.049+k:0.001+l:0.114) val:-0.320 test:-0.324 [Accr] train:18.5% val:92.5% test:92.3% maxVal:92.5% maxTest:92.3%
# [08/40] [Loss] train:-0.227(f:-0.414+r:0.072+k:0.001+l:0.114) val:-0.454 test:-0.457 [Accr] train:51.2% val:89.0% test:88.5% maxVal:89.0% maxTest:88.5%
# [14/40] [Loss] train:0.648 val:0.658 test:0.665 [Accr] train:64.3% val:68.5% test:68.1% maxVal:74.0% maxTest:73.7%
# [08/40] [Loss] train:-0.285(f:-0.476+r:0.076+k:0.001+l:0.114) val:-0.530 test:-0.527 [Accr] train:57.9% val:92.4% test:91.5% maxVal:92.4% maxTest:91.5%
# [14/40] [Loss] train:0.739 val:0.742 test:0.741 [Accr] train:60.2% val:60.7% test:60.8% maxVal:65.5% maxTest:64.4%
# [14/40] [Loss] train:2.223 val:1.789 test:1.799 [Accr] train:19.6% val:76.1% test:74.7% maxVal:76.7% maxTest:76.2%
# [08/40] [Loss] train:-0.429(f:-0.626+r:0.082+k:0.001+l:0.114) val:-0.603 test:-0.599 [Accr] train:75.9% val:98.0% test:97.8% maxVal:98.0% maxTest:97.8%
# [14/40] [Loss] train:0.743 val:0.758 test:0.759 [Accr] train:59.2% val:59.5% test:58.8% maxVal:60.4% maxTest:60.1%
# [05/40] [Loss] train:-0.220(f:-0.411+r:0.075+k:0.001+l:0.115) val:-0.540 test:-0.538 [Accr] train:53.2% val:96.7% test:96.5% maxVal:96.7% maxTest:96.5%
# [05/40] [Loss] train:-0.377(f:-0.571+r:0.078+k:0.001+l:0.115) val:-0.562 test:-0.562 [Accr] train:72.8% val:97.1% test:97.0% maxVal:97.1% maxTest:97.0%
# [05/40] [Loss] train:-0.248(f:-0.437+r:0.072+k:0.001+l:0.115) val:-0.453 test:-0.450 [Accr] train:55.2% val:86.9% test:85.5% maxVal:87.2% maxTest:85.9%
# [08/40] [Loss] train:-0.245(f:-0.436+r:0.075+k:0.001+l:0.114) val:-0.520 test:-0.521 [Accr] train:53.7% val:96.7% test:96.5% maxVal:96.7% maxTest:96.5%
# [14/40] [Loss] train:0.536 val:0.356 test:0.364 [Accr] train:76.2% val:92.2% test:91.4% maxVal:94.8% maxTest:94.6%
# [14/40] [Loss] train:1.674 val:0.755 test:0.769 [Accr] train:53.8% val:97.1% test:96.8% maxVal:97.2% maxTest:96.7%
# [09/40] [Loss] train:0.691 val:0.740 test:0.739 [Accr] train:61.0% val:59.2% test:59.6% maxVal:68.1% maxTest:67.7%
# [09/40] [Loss] train:2.270 val:2.079 test:2.069 [Accr] train:15.4% val:46.6% test:48.2% maxVal:51.2% maxTest:51.8%
# [09/40] [Loss] train:0.653 val:0.394 test:0.400 [Accr] train:73.1% val:93.6% test:93.0% maxVal:94.0% maxTest:93.8%
# [15/40] [Loss] train:0.643 val:0.701 test:0.711 [Accr] train:64.6% val:61.5% test:60.8% maxVal:74.0% maxTest:73.7%
# [15/40] [Loss] train:0.735 val:0.751 test:0.743 [Accr] train:60.2% val:57.7% test:58.2% maxVal:65.5% maxTest:64.4%
# [15/40] [Loss] train:2.217 val:1.798 test:1.804 [Accr] train:20.0% val:75.8% test:75.2% maxVal:76.7% maxTest:76.2%
# [15/40] [Loss] train:0.734 val:0.767 test:0.763 [Accr] train:60.1% val:58.2% test:58.5% maxVal:60.4% maxTest:60.1%
# [09/40] [Loss] train:0.037(f:-0.117+r:0.039+k:0.001+l:0.114) val:-0.158 test:-0.165 [Accr] train:14.6% val:82.5% test:82.7% maxVal:82.5% maxTest:82.7%
# [09/40] [Loss] train:0.020(f:-0.143+r:0.048+k:0.001+l:0.114) val:-0.326 test:-0.326 [Accr] train:18.6% val:93.1% test:92.8% maxVal:93.1% maxTest:92.8%
# [09/40] [Loss] train:-0.232(f:-0.421+r:0.073+k:0.001+l:0.114) val:-0.466 test:-0.466 [Accr] train:51.4% val:89.9% test:89.4% maxVal:89.9% maxTest:89.4%
# [15/40] [Loss] train:0.531 val:0.362 test:0.369 [Accr] train:76.6% val:92.1% test:91.3% maxVal:94.8% maxTest:94.6%
# [15/40] [Loss] train:1.665 val:0.719 test:0.735 [Accr] train:53.9% val:97.1% test:97.0% maxVal:97.2% maxTest:96.7%
# [09/40] [Loss] train:-0.292(f:-0.484+r:0.076+k:0.001+l:0.114) val:-0.542 test:-0.536 [Accr] train:58.1% val:92.6% test:91.6% maxVal:92.6% maxTest:91.6%
# [09/40] [Loss] train:-0.437(f:-0.634+r:0.082+k:0.001+l:0.114) val:-0.615 test:-0.612 [Accr] train:76.0% val:98.2% test:98.0% maxVal:98.2% maxTest:98.0%
# [16/40] [Loss] train:0.640 val:0.704 test:0.716 [Accr] train:65.0% val:62.3% test:61.2% maxVal:74.0% maxTest:73.7%
# [16/40] [Loss] train:0.723 val:0.724 test:0.716 [Accr] train:61.4% val:61.8% test:61.9% maxVal:65.5% maxTest:64.4%
# [16/40] [Loss] train:2.212 val:1.810 test:1.816 [Accr] train:20.2% val:75.4% test:73.8% maxVal:76.7% maxTest:76.2%
# [16/40] [Loss] train:0.727 val:0.743 test:0.743 [Accr] train:60.7% val:61.0% test:60.3% maxVal:61.0% maxTest:60.3%
# [10/40] [Loss] train:0.683 val:0.674 test:0.683 [Accr] train:61.5% val:67.9% test:66.8% maxVal:68.1% maxTest:67.7%
# [10/40] [Loss] train:2.265 val:2.066 test:2.063 [Accr] train:15.4% val:49.1% test:49.4% maxVal:51.2% maxTest:51.8%
# [09/40] [Loss] train:-0.251(f:-0.442+r:0.076+k:0.001+l:0.114) val:-0.536 test:-0.535 [Accr] train:53.8% val:97.0% test:96.8% maxVal:97.0% maxTest:96.8%
# [10/40] [Loss] train:0.640 val:0.400 test:0.401 [Accr] train:73.5% val:93.8% test:93.2% maxVal:94.0% maxTest:93.8%
# [06/40] [Loss] train:-0.231(f:-0.422+r:0.076+k:0.001+l:0.115) val:-0.558 test:-0.557 [Accr] train:53.4% val:97.0% test:97.0% maxVal:97.0% maxTest:97.0%
# [16/40] [Loss] train:0.530 val:0.339 test:0.352 [Accr] train:76.4% val:92.7% test:91.7% maxVal:94.8% maxTest:94.6%
# [16/40] [Loss] train:1.660 val:0.725 test:0.737 [Accr] train:53.9% val:97.1% test:96.9% maxVal:97.2% maxTest:96.7%
# [06/40] [Loss] train:-0.389(f:-0.584+r:0.080+k:0.001+l:0.115) val:-0.578 test:-0.577 [Accr] train:73.1% val:97.4% test:97.4% maxVal:97.4% maxTest:97.4%
# [06/40] [Loss] train:-0.255(f:-0.443+r:0.073+k:0.001+l:0.115) val:-0.467 test:-0.464 [Accr] train:55.6% val:87.8% test:86.3% maxVal:87.8% maxTest:86.3%
# [10/40] [Loss] train:0.035(f:-0.117+r:0.037+k:0.001+l:0.114) val:-0.152 test:-0.161 [Accr] train:14.7% val:82.9% test:83.5% maxVal:82.9% maxTest:83.5%
# [10/40] [Loss] train:0.018(f:-0.144+r:0.047+k:0.001+l:0.114) val:-0.337 test:-0.337 [Accr] train:18.6% val:93.4% test:93.3% maxVal:93.4% maxTest:93.3%
# [17/40] [Loss] train:0.630 val:0.709 test:0.716 [Accr] train:65.9% val:61.4% test:60.6% maxVal:74.0% maxTest:73.7%
# [17/40] [Loss] train:0.715 val:0.711 test:0.703 [Accr] train:62.0% val:63.9% test:64.1% maxVal:65.5% maxTest:64.4%
# [17/40] [Loss] train:2.207 val:1.794 test:1.806 [Accr] train:20.5% val:74.2% test:73.0% maxVal:76.7% maxTest:76.2%
# [17/40] [Loss] train:0.728 val:0.765 test:0.767 [Accr] train:60.5% val:58.9% test:58.3% maxVal:61.0% maxTest:60.3%
# [10/40] [Loss] train:-0.237(f:-0.425+r:0.073+k:0.001+l:0.114) val:-0.474 test:-0.475 [Accr] train:51.5% val:90.0% test:89.6% maxVal:90.0% maxTest:89.6%
# [10/40] [Loss] train:-0.297(f:-0.489+r:0.076+k:0.001+l:0.114) val:-0.551 test:-0.549 [Accr] train:58.2% val:93.5% test:92.5% maxVal:93.5% maxTest:92.5%
# [10/40] [Loss] train:-0.443(f:-0.641+r:0.083+k:0.001+l:0.114) val:-0.620 test:-0.619 [Accr] train:76.2% val:98.3% test:98.1% maxVal:98.3% maxTest:98.1%
# [17/40] [Loss] train:0.519 val:0.351 test:0.357 [Accr] train:76.9% val:92.3% test:91.5% maxVal:94.8% maxTest:94.6%
# [17/40] [Loss] train:1.655 val:0.716 test:0.733 [Accr] train:54.0% val:97.3% test:96.9% maxVal:97.3% maxTest:96.9%
# [11/40] [Loss] train:0.682 val:0.869 test:0.876 [Accr] train:61.1% val:43.6% test:43.6% maxVal:68.1% maxTest:67.7%
# [11/40] [Loss] train:2.261 val:2.063 test:2.063 [Accr] train:16.1% val:48.2% test:49.7% maxVal:51.2% maxTest:51.8%
# [10/40] [Loss] train:-0.256(f:-0.447+r:0.076+k:0.001+l:0.114) val:-0.541 test:-0.542 [Accr] train:54.0% val:97.4% test:97.1% maxVal:97.4% maxTest:97.1%
# [18/40] [Loss] train:0.633 val:0.789 test:0.802 [Accr] train:65.5% val:52.5% test:51.7% maxVal:74.0% maxTest:73.7%
# [11/40] [Loss] train:0.638 val:0.400 test:0.405 [Accr] train:73.2% val:92.9% test:92.1% maxVal:94.0% maxTest:93.8%
# [18/40] [Loss] train:0.709 val:0.701 test:0.693 [Accr] train:62.6% val:65.6% test:66.2% maxVal:65.6% maxTest:66.2%
# [18/40] [Loss] train:2.202 val:1.786 test:1.797 [Accr] train:20.9% val:74.9% test:73.1% maxVal:76.7% maxTest:76.2%
# [18/40] [Loss] train:0.712 val:0.786 test:0.783 [Accr] train:62.0% val:53.9% test:55.0% maxVal:61.0% maxTest:60.3%
# [11/40] [Loss] train:0.033(f:-0.118+r:0.036+k:0.001+l:0.114) val:-0.152 test:-0.163 [Accr] train:14.7% val:83.0% test:83.3% maxVal:83.0% maxTest:83.3%
# [11/40] [Loss] train:0.017(f:-0.145+r:0.046+k:0.001+l:0.114) val:-0.334 test:-0.339 [Accr] train:18.6% val:93.5% test:93.3% maxVal:93.5% maxTest:93.3%
# [18/40] [Loss] train:0.515 val:0.376 test:0.386 [Accr] train:76.8% val:90.9% test:89.6% maxVal:94.8% maxTest:94.6%
# [11/40] [Loss] train:-0.240(f:-0.429+r:0.074+k:0.001+l:0.114) val:-0.483 test:-0.487 [Accr] train:51.7% val:91.3% test:90.8% maxVal:91.3% maxTest:90.8%
# [18/40] [Loss] train:1.645 val:0.731 test:0.745 [Accr] train:54.0% val:97.1% test:96.8% maxVal:97.3% maxTest:96.9%
# [11/40] [Loss] train:-0.304(f:-0.496+r:0.077+k:0.001+l:0.114) val:-0.555 test:-0.556 [Accr] train:58.4% val:93.7% test:92.8% maxVal:93.7% maxTest:92.8%
# [11/40] [Loss] train:-0.449(f:-0.647+r:0.083+k:0.001+l:0.114) val:-0.626 test:-0.627 [Accr] train:76.2% val:98.4% test:98.4% maxVal:98.4% maxTest:98.4%
# [19/40] [Loss] train:0.624 val:0.710 test:0.721 [Accr] train:66.4% val:60.9% test:60.3% maxVal:74.0% maxTest:73.7%
# [07/40] [Loss] train:-0.239(f:-0.431+r:0.076+k:0.001+l:0.115) val:-0.575 test:-0.573 [Accr] train:53.5% val:97.2% test:97.2% maxVal:97.2% maxTest:97.2%
# [19/40] [Loss] train:0.704 val:0.691 test:0.683 [Accr] train:62.7% val:66.2% test:67.0% maxVal:66.2% maxTest:67.0%
# [19/40] [Loss] train:2.198 val:1.780 test:1.789 [Accr] train:21.0% val:74.3% test:73.2% maxVal:76.7% maxTest:76.2%
# [19/40] [Loss] train:0.709 val:0.780 test:0.775 [Accr] train:62.3% val:54.1% test:54.3% maxVal:61.0% maxTest:60.3%
# [07/40] [Loss] train:-0.399(f:-0.595+r:0.080+k:0.001+l:0.115) val:-0.591 test:-0.591 [Accr] train:73.3% val:97.9% test:97.6% maxVal:97.9% maxTest:97.6%
# [12/40] [Loss] train:0.669 val:0.658 test:0.657 [Accr] train:62.4% val:68.2% test:68.5% maxVal:68.2% maxTest:68.5%
# [07/40] [Loss] train:-0.263(f:-0.452+r:0.074+k:0.001+l:0.115) val:-0.477 test:-0.475 [Accr] train:55.7% val:87.3% test:86.1% maxVal:87.8% maxTest:86.3%
# [12/40] [Loss] train:2.256 val:2.058 test:2.057 [Accr] train:16.5% val:47.9% test:48.4% maxVal:51.2% maxTest:51.8%
# [11/40] [Loss] train:-0.259(f:-0.451+r:0.077+k:0.001+l:0.114) val:-0.547 test:-0.549 [Accr] train:54.0% val:97.6% test:97.3% maxVal:97.6% maxTest:97.3%
# [12/40] [Loss] train:0.623 val:0.400 test:0.405 [Accr] train:73.6% val:93.1% test:92.6% maxVal:94.0% maxTest:93.8%
# [19/40] [Loss] train:0.512 val:0.328 test:0.335 [Accr] train:77.2% val:92.9% test:92.2% maxVal:94.8% maxTest:94.6%
# [19/40] [Loss] train:1.640 val:0.733 test:0.748 [Accr] train:54.1% val:97.2% test:96.9% maxVal:97.3% maxTest:96.9%
# [20/40] [Loss] train:0.611 val:0.676 test:0.682 [Accr] train:67.6% val:64.9% test:64.3% maxVal:74.0% maxTest:73.7%
# [20/40] [Loss] train:0.693 val:0.708 test:0.704 [Accr] train:64.3% val:64.4% test:64.4% maxVal:66.2% maxTest:67.0%
# [20/40] [Loss] train:2.189 val:1.779 test:1.787 [Accr] train:21.2% val:75.2% test:74.3% maxVal:76.7% maxTest:76.2%
# [20/40] [Loss] train:0.697 val:0.763 test:0.759 [Accr] train:63.8% val:56.4% test:57.3% maxVal:61.0% maxTest:60.3%
# [12/40] [Loss] train:0.032(f:-0.118+r:0.035+k:0.001+l:0.114) val:-0.149 test:-0.162 [Accr] train:14.7% val:83.6% test:84.1% maxVal:83.6% maxTest:84.1%
# [12/40] [Loss] train:0.014(f:-0.146+r:0.045+k:0.001+l:0.114) val:-0.342 test:-0.346 [Accr] train:18.8% val:93.8% test:93.7% maxVal:93.8% maxTest:93.7%
# [12/40] [Loss] train:-0.245(f:-0.433+r:0.074+k:0.001+l:0.114) val:-0.490 test:-0.491 [Accr] train:51.8% val:91.4% test:90.9% maxVal:91.4% maxTest:90.9%
# [12/40] [Loss] train:-0.307(f:-0.499+r:0.077+k:0.001+l:0.114) val:-0.564 test:-0.561 [Accr] train:58.5% val:93.8% test:93.1% maxVal:93.8% maxTest:93.1%
# [12/40] [Loss] train:-0.455(f:-0.653+r:0.084+k:0.001+l:0.114) val:-0.635 test:-0.635 [Accr] train:76.3% val:98.5% test:98.4% maxVal:98.5% maxTest:98.4%
# [20/40] [Loss] train:0.502 val:0.337 test:0.343 [Accr] train:77.4% val:93.0% test:92.2% maxVal:94.8% maxTest:94.6%
# [20/40] [Loss] train:1.631 val:0.712 test:0.727 [Accr] train:54.2% val:97.4% test:97.0% maxVal:97.4% maxTest:97.0%
# [13/40] [Loss] train:0.662 val:0.687 test:0.687 [Accr] train:63.1% val:63.0% test:63.9% maxVal:68.2% maxTest:68.5%
# [13/40] [Loss] train:2.252 val:2.057 test:2.057 [Accr] train:16.8% val:46.0% test:47.5% maxVal:51.2% maxTest:51.8%
# [21/40] [Loss] train:0.610 val:0.666 test:0.672 [Accr] train:67.8% val:65.6% test:65.3% maxVal:74.0% maxTest:73.7%
# [21/40] [Loss] train:0.691 val:0.709 test:0.705 [Accr] train:64.5% val:64.3% test:64.2% maxVal:66.2% maxTest:67.0%
# [21/40] [Loss] train:2.188 val:1.780 test:1.787 [Accr] train:21.3% val:75.2% test:74.4% maxVal:76.7% maxTest:76.2%
# [21/40] [Loss] train:0.695 val:0.768 test:0.765 [Accr] train:64.1% val:55.2% test:56.1% maxVal:61.0% maxTest:60.3%
# [13/40] [Loss] train:0.616 val:0.360 test:0.366 [Accr] train:74.1% val:94.4% test:94.2% maxVal:94.4% maxTest:94.2%
# [12/40] [Loss] train:-0.265(f:-0.456+r:0.076+k:0.001+l:0.114) val:-0.557 test:-0.558 [Accr] train:54.1% val:97.7% test:97.5% maxVal:97.7% maxTest:97.5%
# [08/40] [Loss] train:-0.244(f:-0.436+r:0.077+k:0.001+l:0.114) val:-0.585 test:-0.581 [Accr] train:53.7% val:97.5% test:97.5% maxVal:97.5% maxTest:97.5%
# [08/40] [Loss] train:-0.408(f:-0.605+r:0.081+k:0.001+l:0.114) val:-0.603 test:-0.601 [Accr] train:73.4% val:98.1% test:97.9% maxVal:98.1% maxTest:97.9%
# [13/40] [Loss] train:0.029(f:-0.119+r:0.033+k:0.001+l:0.114) val:-0.158 test:-0.168 [Accr] train:14.8% val:84.6% test:84.5% maxVal:84.6% maxTest:84.5%
# [13/40] [Loss] train:0.013(f:-0.146+r:0.044+k:0.001+l:0.114) val:-0.337 test:-0.342 [Accr] train:18.8% val:94.2% test:94.2% maxVal:94.2% maxTest:94.2%
# [08/40] [Loss] train:-0.268(f:-0.457+r:0.073+k:0.001+l:0.114) val:-0.490 test:-0.485 [Accr] train:55.9% val:88.3% test:86.9% maxVal:88.3% maxTest:86.9%
# [21/40] [Loss] train:0.501 val:0.334 test:0.340 [Accr] train:77.5% val:93.0% test:92.3% maxVal:94.8% maxTest:94.6%
# [21/40] [Loss] train:1.629 val:0.704 test:0.719 [Accr] train:54.2% val:97.2% test:97.1% maxVal:97.4% maxTest:97.0%
# [13/40] [Loss] train:-0.250(f:-0.439+r:0.073+k:0.001+l:0.114) val:-0.494 test:-0.496 [Accr] train:51.9% val:91.4% test:90.9% maxVal:91.4% maxTest:90.9%
# [22/40] [Loss] train:0.610 val:0.632 test:0.637 [Accr] train:67.6% val:69.5% test:69.6% maxVal:74.0% maxTest:73.7%
# [22/40] [Loss] train:0.690 val:0.700 test:0.696 [Accr] train:64.5% val:65.3% test:65.2% maxVal:66.2% maxTest:67.0%
# [22/40] [Loss] train:0.694 val:0.763 test:0.758 [Accr] train:64.1% val:55.5% test:56.7% maxVal:61.0% maxTest:60.3%
# [22/40] [Loss] train:2.187 val:1.780 test:1.788 [Accr] train:21.3% val:74.9% test:73.9% maxVal:76.7% maxTest:76.2%
# [13/40] [Loss] train:-0.311(f:-0.503+r:0.077+k:0.001+l:0.114) val:-0.570 test:-0.567 [Accr] train:58.7% val:94.1% test:93.3% maxVal:94.1% maxTest:93.3%
# [13/40] [Loss] train:-0.460(f:-0.660+r:0.084+k:0.001+l:0.114) val:-0.644 test:-0.643 [Accr] train:76.4% val:98.5% test:98.5% maxVal:98.5% maxTest:98.5%
# [14/40] [Loss] train:0.650 val:0.702 test:0.707 [Accr] train:63.9% val:63.0% test:62.4% maxVal:68.2% maxTest:68.5%
# [14/40] [Loss] train:2.247 val:2.057 test:2.053 [Accr] train:17.0% val:46.4% test:47.3% maxVal:51.2% maxTest:51.8%
# [14/40] [Loss] train:0.607 val:0.366 test:0.365 [Accr] train:74.1% val:94.9% test:94.6% maxVal:94.9% maxTest:94.6%
# [22/40] [Loss] train:0.500 val:0.331 test:0.337 [Accr] train:77.5% val:93.1% test:92.4% maxVal:94.8% maxTest:94.6%
# [22/40] [Loss] train:1.628 val:0.704 test:0.720 [Accr] train:54.2% val:97.3% test:97.1% maxVal:97.4% maxTest:97.0%
# [13/40] [Loss] train:-0.267(f:-0.459+r:0.076+k:0.001+l:0.114) val:-0.563 test:-0.563 [Accr] train:54.1% val:97.8% test:97.4% maxVal:97.8% maxTest:97.4%
# [23/40] [Loss] train:0.608 val:0.652 test:0.657 [Accr] train:67.9% val:67.2% test:67.2% maxVal:74.0% maxTest:73.7%
# [23/40] [Loss] train:0.689 val:0.714 test:0.710 [Accr] train:64.6% val:63.6% test:63.3% maxVal:66.2% maxTest:67.0%
# [23/40] [Loss] train:2.186 val:1.780 test:1.787 [Accr] train:21.3% val:74.3% test:74.1% maxVal:76.7% maxTest:76.2%
# [23/40] [Loss] train:0.694 val:0.771 test:0.765 [Accr] train:64.2% val:55.2% test:56.1% maxVal:61.0% maxTest:60.3%
# [14/40] [Loss] train:0.027(f:-0.119+r:0.032+k:0.001+l:0.113) val:-0.160 test:-0.165 [Accr] train:14.9% val:84.3% test:84.1% maxVal:84.6% maxTest:84.5%
# [14/40] [Loss] train:0.011(f:-0.147+r:0.044+k:0.001+l:0.113) val:-0.350 test:-0.350 [Accr] train:18.8% val:94.3% test:94.2% maxVal:94.3% maxTest:94.2%
# [14/40] [Loss] train:-0.255(f:-0.442+r:0.073+k:0.001+l:0.113) val:-0.500 test:-0.498 [Accr] train:52.0% val:91.2% test:90.5% maxVal:91.4% maxTest:90.9%
# [14/40] [Loss] train:-0.315(f:-0.506+r:0.076+k:0.001+l:0.113) val:-0.580 test:-0.576 [Accr] train:58.8% val:94.9% test:94.1% maxVal:94.9% maxTest:94.1%
# [14/40] [Loss] train:-0.467(f:-0.666+r:0.085+k:0.001+l:0.113) val:-0.651 test:-0.649 [Accr] train:76.5% val:98.6% test:98.6% maxVal:98.6% maxTest:98.6%
# [23/40] [Loss] train:0.500 val:0.322 test:0.328 [Accr] train:77.5% val:93.7% test:93.0% maxVal:94.8% maxTest:94.6%
# [09/40] [Loss] train:-0.249(f:-0.441+r:0.077+k:0.001+l:0.114) val:-0.598 test:-0.594 [Accr] train:53.8% val:97.8% test:97.6% maxVal:97.8% maxTest:97.6%
# [23/40] [Loss] train:1.627 val:0.708 test:0.723 [Accr] train:54.2% val:97.3% test:97.1% maxVal:97.4% maxTest:97.0%
# [15/40] [Loss] train:0.647 val:0.723 test:0.729 [Accr] train:64.1% val:59.6% test:58.3% maxVal:68.2% maxTest:68.5%
# [24/40] [Loss] train:0.607 val:0.670 test:0.675 [Accr] train:68.1% val:65.3% test:64.7% maxVal:74.0% maxTest:73.7%
# [09/40] [Loss] train:-0.414(f:-0.611+r:0.081+k:0.001+l:0.114) val:-0.616 test:-0.612 [Accr] train:73.5% val:98.2% test:98.1% maxVal:98.2% maxTest:98.1%
# [24/40] [Loss] train:0.688 val:0.710 test:0.707 [Accr] train:64.8% val:63.9% test:63.7% maxVal:66.2% maxTest:67.0%
# [15/40] [Loss] train:2.242 val:2.042 test:2.045 [Accr] train:17.4% val:48.1% test:47.4% maxVal:51.2% maxTest:51.8%
# [24/40] [Loss] train:2.185 val:1.780 test:1.787 [Accr] train:21.3% val:74.1% test:73.8% maxVal:76.7% maxTest:76.2%
# [24/40] [Loss] train:0.692 val:0.764 test:0.760 [Accr] train:64.4% val:55.6% test:56.6% maxVal:61.0% maxTest:60.3%
# [09/40] [Loss] train:-0.277(f:-0.467+r:0.075+k:0.001+l:0.114) val:-0.498 test:-0.490 [Accr] train:56.1% val:87.7% test:86.3% maxVal:88.3% maxTest:86.9%
# [15/40] [Loss] train:0.603 val:0.381 test:0.382 [Accr] train:74.4% val:94.0% test:93.7% maxVal:94.9% maxTest:94.6%
# [14/40] [Loss] train:-0.273(f:-0.464+r:0.077+k:0.001+l:0.113) val:-0.575 test:-0.573 [Accr] train:54.2% val:98.0% test:97.8% maxVal:98.0% maxTest:97.8%
# [15/40] [Loss] train:0.026(f:-0.120+r:0.031+k:0.001+l:0.113) val:-0.158 test:-0.165 [Accr] train:15.1% val:84.4% test:84.4% maxVal:84.6% maxTest:84.5%
# [24/40] [Loss] train:0.498 val:0.347 test:0.353 [Accr] train:77.6% val:92.5% test:91.7% maxVal:94.8% maxTest:94.6%
# [15/40] [Loss] train:0.009(f:-0.147+r:0.042+k:0.001+l:0.113) val:-0.358 test:-0.358 [Accr] train:18.8% val:94.4% test:94.3% maxVal:94.4% maxTest:94.3%
# [24/40] [Loss] train:1.626 val:0.703 test:0.719 [Accr] train:54.2% val:97.2% test:97.1% maxVal:97.4% maxTest:97.0%
# [25/40] [Loss] train:0.607 val:0.656 test:0.662 [Accr] train:68.0% val:66.8% test:66.4% maxVal:74.0% maxTest:73.7%
# [25/40] [Loss] train:0.688 val:0.710 test:0.705 [Accr] train:64.8% val:64.0% test:63.8% maxVal:66.2% maxTest:67.0%
# [15/40] [Loss] train:-0.256(f:-0.444+r:0.073+k:0.001+l:0.113) val:-0.500 test:-0.499 [Accr] train:52.1% val:91.3% test:90.6% maxVal:91.4% maxTest:90.9%
# [25/40] [Loss] train:0.692 val:0.754 test:0.748 [Accr] train:64.4% val:57.5% test:58.5% maxVal:61.0% maxTest:60.3%
# [25/40] [Loss] train:2.185 val:1.782 test:1.789 [Accr] train:21.4% val:74.2% test:73.4% maxVal:76.7% maxTest:76.2%
# [15/40] [Loss] train:-0.319(f:-0.511+r:0.077+k:0.001+l:0.113) val:-0.583 test:-0.579 [Accr] train:58.9% val:94.8% test:94.2% maxVal:94.9% maxTest:94.1%
# [15/40] [Loss] train:-0.470(f:-0.670+r:0.085+k:0.001+l:0.113) val:-0.655 test:-0.655 [Accr] train:76.5% val:98.5% test:98.7% maxVal:98.6% maxTest:98.6%
# [16/40] [Loss] train:0.640 val:0.747 test:0.756 [Accr] train:64.9% val:57.3% test:56.8% maxVal:68.2% maxTest:68.5%
# [16/40] [Loss] train:2.238 val:2.041 test:2.039 [Accr] train:17.7% val:47.7% test:48.4% maxVal:51.2% maxTest:51.8%
# [16/40] [Loss] train:0.600 val:0.373 test:0.374 [Accr] train:74.3% val:93.5% test:93.2% maxVal:94.9% maxTest:94.6%
# ...
# [32/40] [Loss] train:0.605 val:0.713 test:0.716 [Accr] train:68.3% val:60.1% test:59.8% maxVal:68.2% maxTest:68.5%
# [20/40] [Loss] train:-0.289(f:-0.480+r:0.077+k:0.001+l:0.113) val:-0.668 test:-0.665 [Accr] train:54.4% val:98.6% test:98.8% maxVal:98.6% maxTest:98.6%
# [36/40] [Loss] train:-0.293(f:-0.482+r:0.075+k:0.001+l:0.113) val:-0.602 test:-0.604 [Accr] train:54.5% val:98.2% test:98.0% maxVal:98.3% maxTest:98.0%
# [38/40] [Loss] train:-0.339(f:-0.528+r:0.076+k:0.001+l:0.113) val:-0.601 test:-0.598 [Accr] train:59.4% val:94.8% test:94.3% maxVal:95.3% maxTest:94.7%
# [37/40] [Loss] train:-0.493(f:-0.692+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.685 [Accr] train:76.8% val:98.9% test:98.8% maxVal:99.0% maxTest:98.8%
# [39/40] [Loss] train:-0.002(f:-0.152+r:0.037+k:0.001+l:0.113) val:-0.368 test:-0.370 [Accr] train:19.0% val:95.2% test:95.2% maxVal:95.3% maxTest:95.3%
# [39/40] [Loss] train:0.016(f:-0.124+r:0.026+k:0.001+l:0.113) val:-0.163 test:-0.171 [Accr] train:15.6% val:84.5% test:84.3% maxVal:85.0% maxTest:84.5%
# [32/40] [Loss] train:2.208 val:2.032 test:2.029 [Accr] train:20.1% val:45.7% test:45.8% maxVal:51.2% maxTest:51.8%
# [20/40] [Loss] train:-0.466(f:-0.665+r:0.085+k:0.001+l:0.113) val:-0.682 test:-0.681 [Accr] train:74.2% val:98.8% test:98.9% maxVal:98.9% maxTest:98.8%
# [39/40] [Loss] train:-0.276(f:-0.462+r:0.072+k:0.001+l:0.113) val:-0.523 test:-0.522 [Accr] train:52.6% val:92.7% test:91.7% maxVal:93.0% maxTest:92.1%
# [32/40] [Loss] train:0.558 val:0.363 test:0.363 [Accr] train:75.5% val:94.7% test:94.5% maxVal:94.9% maxTest:94.6%
# [20/40] [Loss] train:-0.321(f:-0.508+r:0.074+k:0.001+l:0.113) val:-0.543 test:-0.537 [Accr] train:57.4% val:88.3% test:87.3% maxVal:89.6% maxTest:88.1%
# [37/40] [Loss] train:-0.294(f:-0.482+r:0.075+k:0.001+l:0.113) val:-0.604 test:-0.605 [Accr] train:54.5% val:98.2% test:98.0% maxVal:98.3% maxTest:98.0%
# [39/40] [Loss] train:-0.338(f:-0.528+r:0.076+k:0.001+l:0.113) val:-0.601 test:-0.599 [Accr] train:59.4% val:94.9% test:94.4% maxVal:95.3% maxTest:94.7%
# [38/40] [Loss] train:-0.492(f:-0.692+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.684 [Accr] train:76.8% val:98.9% test:98.9% maxVal:99.0% maxTest:98.8%
# [40/40] [Loss] train:-0.002(f:-0.152+r:0.036+k:0.001+l:0.113) val:-0.375 test:-0.375 [Accr] train:19.0% val:95.1% test:95.2% maxVal:95.3% maxTest:95.3%
# Training finished.
# [Worker_04] Done.
# [40/40] [Loss] train:0.016(f:-0.124+r:0.026+k:0.001+l:0.113) val:-0.164 test:-0.171 [Accr] train:15.6% val:84.5% test:84.4% maxVal:85.0% maxTest:84.5%
# Training finished.
# [Worker_07] Done.
# [40/40] [Loss] train:-0.275(f:-0.461+r:0.072+k:0.001+l:0.113) val:-0.525 test:-0.522 [Accr] train:52.6% val:92.9% test:92.1% maxVal:93.0% maxTest:92.1%
# Training finished.
# [Worker_06] Done.
# [33/40] [Loss] train:0.605 val:0.715 test:0.718 [Accr] train:68.4% val:60.0% test:59.5% maxVal:68.2% maxTest:68.5%
# [38/40] [Loss] train:-0.293(f:-0.482+r:0.075+k:0.001+l:0.113) val:-0.603 test:-0.604 [Accr] train:54.5% val:98.2% test:98.0% maxVal:98.3% maxTest:98.0%
# [40/40] [Loss] train:-0.339(f:-0.529+r:0.076+k:0.001+l:0.113) val:-0.601 test:-0.598 [Accr] train:59.4% val:94.8% test:94.3% maxVal:95.3% maxTest:94.7%
# Training finished.
# [Worker_05] Done.
# [39/40] [Loss] train:-0.493(f:-0.692+r:0.085+k:0.001+l:0.113) val:-0.686 test:-0.685 [Accr] train:76.8% val:99.0% test:98.9% maxVal:99.0% maxTest:98.8%
# [33/40] [Loss] train:2.208 val:2.033 test:2.030 [Accr] train:20.1% val:45.7% test:45.8% maxVal:51.2% maxTest:51.8%
# [33/40] [Loss] train:0.559 val:0.364 test:0.364 [Accr] train:75.5% val:94.7% test:94.5% maxVal:94.9% maxTest:94.6%
# [21/40] [Loss] train:-0.289(f:-0.480+r:0.077+k:0.001+l:0.113) val:-0.670 test:-0.667 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [39/40] [Loss] train:-0.293(f:-0.482+r:0.075+k:0.001+l:0.113) val:-0.604 test:-0.603 [Accr] train:54.5% val:98.2% test:98.0% maxVal:98.3% maxTest:98.0%
# [40/40] [Loss] train:-0.493(f:-0.692+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.685 [Accr] train:76.8% val:98.9% test:98.9% maxVal:99.0% maxTest:98.8%
# Training finished.
# [Worker_02] Done.
# [21/40] [Loss] train:-0.468(f:-0.666+r:0.085+k:0.001+l:0.113) val:-0.684 test:-0.682 [Accr] train:74.2% val:98.8% test:98.9% maxVal:98.9% maxTest:98.8%
# [34/40] [Loss] train:0.605 val:0.720 test:0.723 [Accr] train:68.4% val:59.2% test:58.9% maxVal:68.2% maxTest:68.5%
# [21/40] [Loss] train:-0.322(f:-0.510+r:0.073+k:0.001+l:0.113) val:-0.543 test:-0.535 [Accr] train:57.6% val:87.9% test:87.0% maxVal:89.6% maxTest:88.1%
# [40/40] [Loss] train:-0.293(f:-0.482+r:0.075+k:0.001+l:0.113) val:-0.604 test:-0.602 [Accr] train:54.5% val:98.2% test:98.0% maxVal:98.3% maxTest:98.0%
# Training finished.
# [Worker_03] Done.
# [34/40] [Loss] train:2.208 val:2.034 test:2.030 [Accr] train:20.1% val:45.7% test:45.7% maxVal:51.2% maxTest:51.8%
# [34/40] [Loss] train:0.559 val:0.362 test:0.362 [Accr] train:75.5% val:94.8% test:94.5% maxVal:94.9% maxTest:94.6%
# [35/40] [Loss] train:0.605 val:0.720 test:0.723 [Accr] train:68.4% val:59.2% test:58.9% maxVal:68.2% maxTest:68.5%
# [22/40] [Loss] train:-0.289(f:-0.480+r:0.077+k:0.001+l:0.113) val:-0.668 test:-0.667 [Accr] train:54.4% val:98.6% test:98.7% maxVal:98.7% maxTest:98.7%
# [35/40] [Loss] train:2.208 val:2.034 test:2.031 [Accr] train:20.1% val:45.7% test:45.6% maxVal:51.2% maxTest:51.8%
# [22/40] [Loss] train:-0.468(f:-0.666+r:0.085+k:0.001+l:0.113) val:-0.683 test:-0.683 [Accr] train:74.2% val:98.8% test:98.9% maxVal:98.9% maxTest:98.8%
# [35/40] [Loss] train:0.558 val:0.361 test:0.361 [Accr] train:75.6% val:94.7% test:94.5% maxVal:94.9% maxTest:94.6%
# [22/40] [Loss] train:-0.322(f:-0.510+r:0.073+k:0.001+l:0.113) val:-0.540 test:-0.536 [Accr] train:57.6% val:88.0% test:87.0% maxVal:89.6% maxTest:88.1%
# [36/40] [Loss] train:0.605 val:0.717 test:0.720 [Accr] train:68.4% val:59.6% test:59.3% maxVal:68.2% maxTest:68.5%
# [36/40] [Loss] train:2.207 val:2.033 test:2.030 [Accr] train:20.1% val:45.7% test:45.7% maxVal:51.2% maxTest:51.8%
# [36/40] [Loss] train:0.558 val:0.361 test:0.362 [Accr] train:75.5% val:94.8% test:94.5% maxVal:94.9% maxTest:94.6%
# [23/40] [Loss] train:-0.290(f:-0.481+r:0.077+k:0.001+l:0.113) val:-0.670 test:-0.667 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [37/40] [Loss] train:0.605 val:0.716 test:0.719 [Accr] train:68.4% val:59.7% test:59.4% maxVal:68.2% maxTest:68.5%
# [23/40] [Loss] train:-0.468(f:-0.667+r:0.085+k:0.001+l:0.113) val:-0.683 test:-0.683 [Accr] train:74.2% val:98.8% test:98.9% maxVal:98.9% maxTest:98.8%
# [23/40] [Loss] train:-0.323(f:-0.511+r:0.074+k:0.001+l:0.113) val:-0.541 test:-0.538 [Accr] train:57.6% val:88.1% test:87.2% maxVal:89.6% maxTest:88.1%
# [37/40] [Loss] train:2.208 val:2.034 test:2.031 [Accr] train:20.1% val:45.6% test:45.6% maxVal:51.2% maxTest:51.8%
# [37/40] [Loss] train:0.558 val:0.361 test:0.361 [Accr] train:75.6% val:94.7% test:94.5% maxVal:94.9% maxTest:94.6%
# [38/40] [Loss] train:0.605 val:0.717 test:0.720 [Accr] train:68.5% val:59.5% test:59.3% maxVal:68.2% maxTest:68.5%
# [24/40] [Loss] train:-0.290(f:-0.481+r:0.077+k:0.001+l:0.113) val:-0.669 test:-0.667 [Accr] train:54.4% val:98.6% test:98.7% maxVal:98.7% maxTest:98.7%
# [38/40] [Loss] train:2.207 val:2.034 test:2.030 [Accr] train:20.1% val:45.7% test:45.6% maxVal:51.2% maxTest:51.8%
# [38/40] [Loss] train:0.558 val:0.363 test:0.363 [Accr] train:75.5% val:94.8% test:94.5% maxVal:94.9% maxTest:94.6%
# [24/40] [Loss] train:-0.468(f:-0.667+r:0.085+k:0.001+l:0.113) val:-0.684 test:-0.684 [Accr] train:74.2% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [24/40] [Loss] train:-0.323(f:-0.510+r:0.073+k:0.001+l:0.113) val:-0.544 test:-0.539 [Accr] train:57.7% val:88.5% test:87.4% maxVal:89.6% maxTest:88.1%
# [39/40] [Loss] train:0.605 val:0.716 test:0.720 [Accr] train:68.4% val:59.5% test:59.3% maxVal:68.2% maxTest:68.5%
# [39/40] [Loss] train:2.207 val:2.033 test:2.030 [Accr] train:20.1% val:45.7% test:45.7% maxVal:51.2% maxTest:51.8%
# [39/40] [Loss] train:0.558 val:0.361 test:0.362 [Accr] train:75.6% val:94.7% test:94.5% maxVal:94.9% maxTest:94.6%
# [25/40] [Loss] train:-0.290(f:-0.481+r:0.077+k:0.001+l:0.113) val:-0.670 test:-0.668 [Accr] train:54.4% val:98.6% test:98.7% maxVal:98.7% maxTest:98.7%
# [40/40] [Loss] train:0.605 val:0.719 test:0.723 [Accr] train:68.3% val:59.2% test:58.9% maxVal:68.2% maxTest:68.5%
# Training finished.
# [Worker_17] Done.
# [25/40] [Loss] train:-0.469(f:-0.668+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.685 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [40/40] [Loss] train:0.558 val:0.362 test:0.363 [Accr] train:75.5% val:94.7% test:94.4% maxVal:94.9% maxTest:94.6%
# Training finished.
# [Worker_09] Done.
# [25/40] [Loss] train:-0.324(f:-0.511+r:0.073+k:0.001+l:0.113) val:-0.546 test:-0.540 [Accr] train:57.6% val:88.4% test:87.5% maxVal:89.6% maxTest:88.1%
# [40/40] [Loss] train:2.207 val:2.034 test:2.031 [Accr] train:20.1% val:45.6% test:45.7% maxVal:51.2% maxTest:51.8%
# Training finished.
# [Worker_16] Done.
# [26/40] [Loss] train:-0.290(f:-0.481+r:0.077+k:0.001+l:0.113) val:-0.671 test:-0.670 [Accr] train:54.4% val:98.6% test:98.7% maxVal:98.7% maxTest:98.7%
# [27/40] [Loss] train:-0.291(f:-0.481+r:0.077+k:0.001+l:0.113) val:-0.669 test:-0.670 [Accr] train:54.4% val:98.7% test:98.8% maxVal:98.7% maxTest:98.7%
# [26/40] [Loss] train:-0.469(f:-0.668+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.686 [Accr] train:74.2% val:98.9% test:98.9% maxVal:98.9% maxTest:99.0%
# [26/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.543 test:-0.536 [Accr] train:57.7% val:87.9% test:87.0% maxVal:89.6% maxTest:88.1%
# [28/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.671 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [29/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.672 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [27/40] [Loss] train:-0.469(f:-0.668+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.686 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [27/40] [Loss] train:-0.324(f:-0.511+r:0.073+k:0.001+l:0.113) val:-0.540 test:-0.535 [Accr] train:57.7% val:87.8% test:86.9% maxVal:89.6% maxTest:88.1%
# [30/40] [Loss] train:-0.291(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.672 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [31/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.673 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [28/40] [Loss] train:-0.470(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.686 test:-0.685 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [32/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.673 test:-0.673 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [28/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.543 test:-0.536 [Accr] train:57.7% val:88.4% test:87.3% maxVal:89.6% maxTest:88.1%
# [33/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.671 test:-0.669 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [29/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [34/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.670 test:-0.669 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [29/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.546 test:-0.541 [Accr] train:57.7% val:88.5% test:87.5% maxVal:89.6% maxTest:88.1%
# [35/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.672 test:-0.672 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [30/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.688 test:-0.687 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [36/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.672 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [30/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.544 test:-0.537 [Accr] train:57.7% val:88.2% test:87.2% maxVal:89.6% maxTest:88.1%
# [37/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.673 test:-0.673 [Accr] train:54.4% val:98.6% test:98.7% maxVal:98.7% maxTest:98.7%
# [38/40] [Loss] train:-0.292(f:-0.482+r:0.077+k:0.001+l:0.113) val:-0.673 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [31/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.686 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [31/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.539 test:-0.533 [Accr] train:57.7% val:87.8% test:86.8% maxVal:89.6% maxTest:88.1%
# [39/40] [Loss] train:-0.292(f:-0.483+r:0.077+k:0.001+l:0.113) val:-0.673 test:-0.672 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# [40/40] [Loss] train:-0.292(f:-0.483+r:0.077+k:0.001+l:0.113) val:-0.672 test:-0.671 [Accr] train:54.4% val:98.7% test:98.7% maxVal:98.7% maxTest:98.7%
# Training finished.
# [Worker_01] Done.
# [32/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.689 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [32/40] [Loss] train:-0.325(f:-0.513+r:0.073+k:0.001+l:0.113) val:-0.544 test:-0.540 [Accr] train:57.7% val:88.4% test:87.3% maxVal:89.6% maxTest:88.1%
# [33/40] [Loss] train:-0.471(f:-0.670+r:0.085+k:0.001+l:0.113) val:-0.686 test:-0.687 [Accr] train:74.3% val:98.9% test:98.9% maxVal:98.9% maxTest:99.0%
# [33/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.543 test:-0.538 [Accr] train:57.7% val:88.1% test:87.2% maxVal:89.6% maxTest:88.1%
# [34/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.685 test:-0.685 [Accr] train:74.3% val:98.8% test:98.9% maxVal:98.9% maxTest:99.0%
# [34/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.537 test:-0.534 [Accr] train:57.7% val:87.8% test:86.9% maxVal:89.6% maxTest:88.1%
# [35/40] [Loss] train:-0.470(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.686 test:-0.687 [Accr] train:74.3% val:98.9% test:98.9% maxVal:98.9% maxTest:99.0%
# [35/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.542 test:-0.538 [Accr] train:57.7% val:88.3% test:87.2% maxVal:89.6% maxTest:88.1%
# [36/40] [Loss] train:-0.471(f:-0.670+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [36/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.540 test:-0.534 [Accr] train:57.7% val:88.0% test:87.0% maxVal:89.6% maxTest:88.1%
# [37/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:98.9% maxVal:98.9% maxTest:99.0%
# [37/40] [Loss] train:-0.326(f:-0.513+r:0.073+k:0.001+l:0.113) val:-0.544 test:-0.540 [Accr] train:57.7% val:88.0% test:87.0% maxVal:89.6% maxTest:88.1%
# [38/40] [Loss] train:-0.470(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# [38/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.544 test:-0.537 [Accr] train:57.7% val:88.2% test:87.3% maxVal:89.6% maxTest:88.1%
# [39/40] [Loss] train:-0.471(f:-0.669+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:98.9% maxVal:98.9% maxTest:99.0%
# [39/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.545 test:-0.539 [Accr] train:57.7% val:88.4% test:87.4% maxVal:89.6% maxTest:88.1%
# [40/40] [Loss] train:-0.471(f:-0.670+r:0.085+k:0.001+l:0.113) val:-0.687 test:-0.687 [Accr] train:74.3% val:98.9% test:99.0% maxVal:98.9% maxTest:99.0%
# Training finished.
# [Worker_00] Done.
# [40/40] [Loss] train:-0.325(f:-0.512+r:0.073+k:0.001+l:0.113) val:-0.543 test:-0.538 [Accr] train:57.7% val:88.2% test:87.3% maxVal:89.6% maxTest:88.1%
# Training finished.
# [Worker_08] Done.
